# %% [markdown]
# # Plot TimeLine Activity (automatic)
#
# This codes allows to plot the activity (i.e. distance traveled per 10-min time bin) for each individual over the whole experiment. It saves the figure as a pdf file for each experiment. It also provides a txt file with the distance traveled in each time bin for each individual as well as the total distance traveled.
#
# | ![](../images/timeline.jpg) |
# |:--:|
# |TimeLine example|

# %%
'''
Created on 29 Aug. 2019

@author: Elodie Ey
'''

import sys
sys.path.insert(1, "../")


import sqlite3
from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *

import lmtanalysis
from tkinter.filedialog import askopenfilename
from tabulate import tabulate
from collections import Counter
import collections
import xlsxwriter
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import os
from lmtanalysis.FileUtil import getFilesToProcess
from lmtanalysis.Util import convert_to_d_h_m_s, getMinTMaxTAndFileNameInput
from scripts.addMetaDataEvent import *



def frameToTimeTicker(x, pos):
   
    vals= convert_to_d_h_m_s( x )
    return "D{0} - {1:02d}:{2:02d}".format( int(vals[0])+1, int(vals[1]), int(vals[2]) )
    

print("Code launched.")
saveFile = "figTimeLineActivity"
#Choose the files to process
files = getFilesToProcess()

tmin, tmax, text_file = getMinTMaxTAndFileNameInput()
# Out:
# Code launched.
# Enter time information in frame. You can also set in days, hour, minutes
# valid entries: 100, 1d, 1.5d, 23.5h, 1d 2h 3m 4s 5f
# Starting t : 0
# Entry (in frame) : 0
# Ending t : 2d
# Entry (in frame) : 5184000
# Enter file name to save data (.txt will be added) : timeline_groups

# %%
for file in files:
    print(file)
    expName = os.path.basename(file)[:-7]
    print( expName )

    connection = sqlite3.connect( file )

    pool = AnimalPool( )
    pool.loadAnimals( connection )

    pool.loadDetection( start = tmin, end = tmax, lightLoad=True)

    #Load the timeline of the nest4 event over all individuals
    print( "Loading all nest4 for file " + file )
    nest4TimeLine = {}
    nest4TimeLine["all"] = EventTimeLine( connection, "Nest4_", minFrame=tmin, maxFrame=tmax )

    #Load the timeline of the nest3 event over all individuals
    print( "Loading all nest3 for file " + file )
    nest3TimeLine = {}
    nest3TimeLine["all"] = EventTimeLine( connection, "Nest3_", minFrame=tmin, maxFrame=tmax )

    print("loading night events for file " + file)
    nightTimeLine = EventTimeLine( connection, "night" , minFrame=tmin, maxFrame=tmax )

    ''' build the plot '''
    ymax=200
    ymin=-30
    fig, ax = plt.subplots( 1,1 , figsize=(16, 4 ) )
    ax = plt.gca() # get current axis
    ax.set_xlabel("time")
    ax.set_xlim([0, tmax])
    ax.set_ylim([ymin, ymax])

    #set x axis
    formatter = matplotlib.ticker.FuncFormatter( frameToTimeTicker )
    ax.xaxis.set_major_formatter(formatter)
    ax.tick_params(labelsize=6 )
    ax.xaxis.set_major_locator(ticker.MultipleLocator( 30 * 60 * 60 * 12 ))
    ax.xaxis.set_minor_locator(ticker.MultipleLocator( 30 * 60 * 60 ))


    #draw the rectangles for the nights
    for nightEvent in nightTimeLine.getEventList():
        ax.axvspan( nightEvent.startFrame, nightEvent.endFrame, alpha=0.1, color='black')
        ax.text( nightEvent.startFrame+(nightEvent.endFrame-nightEvent.startFrame)/2 , 0.90*ymax , "dark phase" ,fontsize=6, ha='center')

    #plot the distance traveled per timeBin min time bin
    timeBin = 10
    dt = {}
    totalDistance = {}

    for animal in pool.animalDictionnary.keys():
        print ( pool.animalDictionnary[animal].RFID )
        dt[animal] = [x/100 for x in pool.animalDictionnary[animal].getDistancePerBin(binFrameSize = timeBin*oneMinute, maxFrame = tmax )]
        totalDistance[animal] = pool.animalDictionnary[animal].getDistance(tmin=tmin, tmax=tmax)


    nTimeBins = len(dt[1])
    print(nTimeBins)

    abs = [10*oneMinute]
    for t in range(1, nTimeBins):
        x = abs[t-1] + timeBin*oneMinute
        abs.append(x)

    #print(abs)
    print(len(abs))

    text_file.write( "{}\t{}\t{}\t{}\t{}\t{}\t{}\n".format( "file", "rfid", "genotype", "user1", "tmin", "tmax", "totalDistance" ) )

    for animal in pool.animalDictionnary.keys():
        #print(dt[animal])
        ax.plot( abs, dt[animal], color = getAnimalColor(animal), linewidth=0.6 )

        #prepare data to be written in a txt file, with tab separating columns
        line =""
        line+= str ( file )+ "\t"
        line+= str ( pool.animalDictionnary[animal].RFID )+ "\t"
        line+= str ( pool.animalDictionnary[animal].genotype )+ "\t"
        line+= str ( pool.animalDictionnary[animal].user1 )+ "\t"
        line+= str ( tmin )+ "\t"
        line+= str ( tmax )+ "\t"
        line+= str ( totalDistance[animal]/100 )+ "\t"

        for val in dt[animal]:
            line+= str( val )+ "\t"

        text_file.write( line )
        text_file.write( "\n" ) 

    text_file.close()
    
    #Print the name and genotype of the animals on the graph, with the corresponding colors and the total distance traveled over the experiment
    legendHeight = 0.6*ymax
    for animal in pool.animalDictionnary.keys():
        print ( pool.animalDictionnary[animal].RFID )
        ax.text(30*60*60, legendHeight, "{} {} ({} m)".format(pool.animalDictionnary[animal].RFID[5:], pool.animalDictionnary[animal].genotype, round(totalDistance[animal]/100)), color=getAnimalColor(animal), fontsize=5 )
        legendHeight += 12 


    yLabels=[]
    line = -20
    yTickList = []
    addThickness=0

    fig.suptitle("Activity time line {}".format( expName ))
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    #draw the nest4 time line
    yLabels.append("Nest4")
    lineData = []

    for eventList in nest4TimeLine["all"].eventList:                                
        lineData.append( ( eventList.startFrame-addThickness , eventList.duration()+addThickness ))    

    ax.broken_barh( lineData , ( line-4, 4 ), facecolors = "black" )    
    yTickList.append(line)

    line+=10

    #draw the nest3 time line
    yLabels.append("Nest3")
    addThickness=0
    lineData = []

    for eventList in nest3TimeLine["all"].eventList:                                
        lineData.append( ( eventList.startFrame-addThickness , eventList.duration()+addThickness ))    

    ax.broken_barh( lineData , ( line-4, 4 ), facecolors = "black" )    
    yTickList.append(line)

    line+=10
    
    #draw the groups time line - Attempt by Alice on 21/07/2020
    yLabels.append("Groups")
    addThickness=0
    lineData = []

    for eventList in groupTimeLine["all"].eventList:                                
        lineData.append( ( eventList.startFrame-addThickness , eventList.duration()+addThickness ))    

    ax.broken_barh( lineData , ( line-4, 4 ), facecolors = "black" )    
    yTickList.append(line)

    line+=10

    #draw the y axis  
    yLab=[0, 40, 80, 120, 160, 200]
    for i in yLab:
        yTickList.append(i)    
        yLabels.append(i)

    ax.set_yticks( yTickList )
    ax.set_yticklabels( yLabels )

    plt.tight_layout()
    print ("Saving figure...")
    figureFileName = "FigActivityTimeLine_{}.pdf".format( expName )
    print( "Saving figure to ", figureFileName )
    fig.savefig( figureFileName ,dpi=100)
    plt.show()
    plt.close( fig )
# Out:
# D:/live mouse tracker data/Experiment 19/Experiment 19.sqlite
# Experiment 19
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None
# Animal Id:2 Name:B RFID:000022986408 Genotype:HT User1:None
# Animal Id:3 Name:C RFID:000022986409 Genotype:HT User1:None
# Animal Id:4 Name:D RFID:000022986416 Genotype:HT User1:None
# Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5184000
# Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None   3306469  detections loaded in 104.19302463531494 seconds.
# Animal Id:2 Name:B RFID:000022986408 Genotype:HT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5184000
# Animal Id:2 Name:B RFID:000022986408 Genotype:HT User1:None   3289957  detections loaded in 682.1825921535492 seconds.
# Animal Id:3 Name:C RFID:000022986409 Genotype:HT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5184000
# Animal Id:3 Name:C RFID:000022986409 Genotype:HT User1:None   3139842  detections loaded in 617.5703547000885 seconds.
# Animal Id:4 Name:D RFID:000022986416 Genotype:HT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5184000
# Animal Id:4 Name:D RFID:000022986416 Genotype:HT User1:None   3417973  detections loaded in 770.4632680416107 seconds.
# Loading all nest4 for file D:/live mouse tracker data/Experiment 19/Experiment 19.sqlite
# Nest4_  Id( None , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 18980  records loaded in  1484.243151664734 S )
# Loading all nest3 for file D:/live mouse tracker data/Experiment 19/Experiment 19.sqlite
# Nest3_  Id( None , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 39868  records loaded in  9.435134172439575 S )
# loading night events for file D:/live mouse tracker data/Experiment 19/Experiment 19.sqlite
# night  Id( None , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2  records loaded in  9.514681577682495 S )
# 000022986492
# Compute total distance min:0 max:18000
# Distance bin n:0 value:5761.706871176047
# Compute total distance min:18000 max:36000
# Distance bin n:18000 value:5018.940471607444
# Compute total distance min:36000 max:54000
# Distance bin n:36000 value:4673.4379094212245
# Compute total distance min:54000 max:72000
# Distance bin n:54000 value:4433.667968138631
# Compute total distance min:72000 max:90000
# Distance bin n:72000 value:4470.797942257001
# Compute total distance min:90000 max:108000
# Distance bin n:90000 value:4121.45252997609
# Compute total distance min:108000 max:126000
# Distance bin n:108000 value:3575.7690804038275
# Compute total distance min:126000 max:144000
# Distance bin n:126000 value:3483.466705404195
# Compute total distance min:144000 max:162000
# Distance bin n:144000 value:3591.194710702444
# Compute total distance min:162000 max:180000
# Distance bin n:162000 value:4104.9750677358015
# Compute total distance min:180000 max:198000
# Distance bin n:180000 value:3995.060699173759
# Compute total distance min:198000 max:216000
# Distance bin n:198000 value:3216.141001283689
# Compute total distance min:216000 max:234000
# Distance bin n:216000 value:3755.7654201055275
# Compute total distance min:234000 max:252000
# Distance bin n:234000 value:2725.4507416345446
# Compute total distance min:252000 max:270000
# Distance bin n:252000 value:2945.794076182404
# Compute total distance min:270000 max:288000
# Distance bin n:270000 value:3134.6409317929288
# Compute total distance min:288000 max:306000
# Distance bin n:288000 value:1544.1924407001086
# Compute total distance min:306000 max:324000
# Distance bin n:306000 value:1652.5832552804898
# Compute total distance min:324000 max:342000
# Distance bin n:324000 value:2461.1335384658623
# Compute total distance min:342000 max:360000
# Distance bin n:342000 value:3838.6348407900173
# Compute total distance min:360000 max:378000
# Distance bin n:360000 value:3592.6492075858714
# Compute total distance min:378000 max:396000
# Distance bin n:378000 value:2608.3000930119697
# Compute total distance min:396000 max:414000
# Distance bin n:396000 value:2717.468563729867
# Compute total distance min:414000 max:432000
# Distance bin n:414000 value:2300.2411163051534
# Compute total distance min:432000 max:450000
# Distance bin n:432000 value:3657.816640089254
# Compute total distance min:450000 max:468000
# Distance bin n:450000 value:3009.5085095246636
# Compute total distance min:468000 max:486000
# Distance bin n:468000 value:1331.9995045154574
# Compute total distance min:486000 max:504000
# Distance bin n:486000 value:887.843596807299
# Compute total distance min:504000 max:522000
# Distance bin n:504000 value:1285.0101676837296
# Compute total distance min:522000 max:540000
# Distance bin n:522000 value:2384.4628409309144
# Compute total distance min:540000 max:558000
# Distance bin n:540000 value:1545.2976858567288
# Compute total distance min:558000 max:576000
# Distance bin n:558000 value:0.0
# Compute total distance min:576000 max:594000
# Distance bin n:576000 value:1761.6290067554103
# Compute total distance min:594000 max:612000
# Distance bin n:594000 value:2871.836956582738
# Compute total distance min:612000 max:630000
# Distance bin n:612000 value:2570.053826208407
# Compute total distance min:630000 max:648000
# Distance bin n:630000 value:2216.406903216827
# Compute total distance min:648000 max:666000
# Distance bin n:648000 value:3287.3866710045704
# Compute total distance min:666000 max:684000
# Distance bin n:666000 value:2862.8009168281783
# Compute total distance min:684000 max:702000
# Distance bin n:684000 value:2247.1723562614643
# Compute total distance min:702000 max:720000
# Distance bin n:702000 value:904.6781551799623
# Compute total distance min:720000 max:738000
# Distance bin n:720000 value:37.00179950714435
# Compute total distance min:738000 max:756000
# Distance bin n:738000 value:2460.6029565316794
# Compute total distance min:756000 max:774000
# Distance bin n:756000 value:1473.4388951247745
# Compute total distance min:774000 max:792000
# Distance bin n:774000 value:0.0
# Compute total distance min:792000 max:810000
# Distance bin n:792000 value:873.3583133291739
# Compute total distance min:810000 max:828000
# Distance bin n:810000 value:96.97840393798448
# Compute total distance min:828000 max:846000
# Distance bin n:828000 value:468.3996816627405
# Compute total distance min:846000 max:864000
# Distance bin n:846000 value:262.8253053937077
# Compute total distance min:864000 max:882000
# Distance bin n:864000 value:0.0
# Compute total distance min:882000 max:900000
# Distance bin n:882000 value:0.0
# Compute total distance min:900000 max:918000
# Distance bin n:900000 value:0.0
# Compute total distance min:918000 max:936000
# Distance bin n:918000 value:4482.96747551148
# Compute total distance min:936000 max:954000
# Distance bin n:936000 value:2768.8160779871378
# Compute total distance min:954000 max:972000
# Distance bin n:954000 value:2326.4125733927413
# Compute total distance min:972000 max:990000
# Distance bin n:972000 value:2225.835502171302
# Compute total distance min:990000 max:1008000
# Distance bin n:990000 value:1923.2554810894992
# Compute total distance min:1008000 max:1026000
# Distance bin n:1008000 value:2177.279443975011
# Compute total distance min:1026000 max:1044000
# Distance bin n:1026000 value:1490.0439305803009
# Compute total distance min:1044000 max:1062000
# Distance bin n:1044000 value:1863.4282963506607
# Compute total distance min:1062000 max:1080000
# Distance bin n:1062000 value:3131.9760490071208
# Compute total distance min:1080000 max:1098000
# Distance bin n:1080000 value:2878.3053532193003
# Compute total distance min:1098000 max:1116000
# Distance bin n:1098000 value:1715.0599037225475
# Compute total distance min:1116000 max:1134000
# Distance bin n:1116000 value:3665.559391804861
# Compute total distance min:1134000 max:1152000
# Distance bin n:1134000 value:2020.4725875783597
# Compute total distance min:1152000 max:1170000
# Distance bin n:1152000 value:417.44946609031143
# Compute total distance min:1170000 max:1188000
# Distance bin n:1170000 value:0.0
# Compute total distance min:1188000 max:1206000
# Distance bin n:1188000 value:0.0
# Compute total distance min:1206000 max:1224000
# Distance bin n:1206000 value:0.0
# Compute total distance min:1224000 max:1242000
# Distance bin n:1224000 value:0.0
# Compute total distance min:1242000 max:1260000
# Distance bin n:1242000 value:1781.0285602285578
# Compute total distance min:1260000 max:1278000
# Distance bin n:1260000 value:1300.3858962836623
# Compute total distance min:1278000 max:1296000
# Distance bin n:1278000 value:284.2783079793399
# Compute total distance min:1296000 max:1314000
# Distance bin n:1296000 value:0.0
# Compute total distance min:1314000 max:1332000
# Distance bin n:1314000 value:2291.4333259883747
# Compute total distance min:1332000 max:1350000
# Distance bin n:1332000 value:4939.9697893473785
# Compute total distance min:1350000 max:1368000
# Distance bin n:1350000 value:4735.772431295077
# Compute total distance min:1368000 max:1386000
# Distance bin n:1368000 value:3841.291581864029
# Compute total distance min:1386000 max:1404000
# Distance bin n:1386000 value:4675.8386750906275
# Compute total distance min:1404000 max:1422000
# Distance bin n:1404000 value:4798.73246902878
# Compute total distance min:1422000 max:1440000
# Distance bin n:1422000 value:3924.1137346824285
# Compute total distance min:1440000 max:1458000
# Distance bin n:1440000 value:2446.3612023528217
# Compute total distance min:1458000 max:1476000
# Distance bin n:1458000 value:3405.530078965516
# Compute total distance min:1476000 max:1494000
# Distance bin n:1476000 value:4243.065269967704
# Compute total distance min:1494000 max:1512000
# Distance bin n:1494000 value:1610.7426398378695
# Compute total distance min:1512000 max:1530000
# Distance bin n:1512000 value:2847.717121672585
# Compute total distance min:1530000 max:1548000
# Distance bin n:1530000 value:2870.481592798282
# Compute total distance min:1548000 max:1566000
# Distance bin n:1548000 value:3658.2291644752136
# Compute total distance min:1566000 max:1584000
# Distance bin n:1566000 value:3473.2050401836277
# Compute total distance min:1584000 max:1602000
# Distance bin n:1584000 value:2849.739093498562
# Compute total distance min:1602000 max:1620000
# Distance bin n:1602000 value:3294.334887078925
# Compute total distance min:1620000 max:1638000
# Distance bin n:1620000 value:2960.0560638582883
# Compute total distance min:1638000 max:1656000
# Distance bin n:1638000 value:2770.2993813410385
# Compute total distance min:1656000 max:1674000
# Distance bin n:1656000 value:1766.0710741591788
# Compute total distance min:1674000 max:1692000
# Distance bin n:1674000 value:1925.3622378384073
# Compute total distance min:1692000 max:1710000
# Distance bin n:1692000 value:4401.163086627718
# Compute total distance min:1710000 max:1728000
# Distance bin n:1710000 value:2895.2000681167087
# Compute total distance min:1728000 max:1746000
# Distance bin n:1728000 value:1982.7390737154972
# Compute total distance min:1746000 max:1764000
# Distance bin n:1746000 value:3052.4063209630954
# Compute total distance min:1764000 max:1782000
# Distance bin n:1764000 value:775.7387811712236
# Compute total distance min:1782000 max:1800000
# Distance bin n:1782000 value:3174.99170177211
# Compute total distance min:1800000 max:1818000
# Distance bin n:1800000 value:2100.0292005980996
# Compute total distance min:1818000 max:1836000
# Distance bin n:1818000 value:3234.248274836451
# Compute total distance min:1836000 max:1854000
# Distance bin n:1836000 value:2783.2051186681097
# Compute total distance min:1854000 max:1872000
# Distance bin n:1854000 value:18044.453353015917
# Compute total distance min:1872000 max:1890000
# Distance bin n:1872000 value:7708.6799807932
# Compute total distance min:1890000 max:1908000
# Distance bin n:1890000 value:26988.421198686778
# Compute total distance min:1908000 max:1926000
# Distance bin n:1908000 value:27076.67100142536
# Compute total distance min:1926000 max:1944000
# Distance bin n:1926000 value:21324.59737788029
# Compute total distance min:1944000 max:1962000
# Distance bin n:1944000 value:3487.4858950852486
# Compute total distance min:1962000 max:1980000
# Distance bin n:1962000 value:3095.637301241798
# Compute total distance min:1980000 max:1998000
# Distance bin n:1980000 value:4305.475509153135
# Compute total distance min:1998000 max:2016000
# Distance bin n:1998000 value:2730.3839710408206
# Compute total distance min:2016000 max:2034000
# Distance bin n:2016000 value:3518.3066539184015
# Compute total distance min:2034000 max:2052000
# Distance bin n:2034000 value:2599.093397250744
# Compute total distance min:2052000 max:2070000
# Distance bin n:2052000 value:2157.4387814858533
# Compute total distance min:2070000 max:2088000
# Distance bin n:2070000 value:1232.1499123843078
# Compute total distance min:2088000 max:2106000
# Distance bin n:2088000 value:1317.7535854109533
# Compute total distance min:2106000 max:2124000
# Distance bin n:2106000 value:738.0980946937319
# Compute total distance min:2124000 max:2142000
# Distance bin n:2124000 value:3481.638673320939
# Compute total distance min:2142000 max:2160000
# Distance bin n:2142000 value:2959.2733641353593
# Compute total distance min:2160000 max:2178000
# Distance bin n:2160000 value:2038.8065363124979
# Compute total distance min:2178000 max:2196000
# Distance bin n:2178000 value:855.0064385289597
# Compute total distance min:2196000 max:2214000
# Distance bin n:2196000 value:2969.0331376667878
# Compute total distance min:2214000 max:2232000
# Distance bin n:2214000 value:1932.6890262321967
# Compute total distance min:2232000 max:2250000
# Distance bin n:2232000 value:3517.150004100867
# Compute total distance min:2250000 max:2268000
# Distance bin n:2250000 value:2669.821153504457
# Compute total distance min:2268000 max:2286000
# Distance bin n:2268000 value:2746.9904379219743
# Compute total distance min:2286000 max:2304000
# Distance bin n:2286000 value:3978.3867857467662
# Compute total distance min:2304000 max:2322000
# Distance bin n:2304000 value:2603.7826675751576
# Compute total distance min:2322000 max:2340000
# Distance bin n:2322000 value:2226.250258164237
# Compute total distance min:2340000 max:2358000
# Distance bin n:2340000 value:0.0
# Compute total distance min:2358000 max:2376000
# Distance bin n:2358000 value:84.10574904168982
# Compute total distance min:2376000 max:2394000
# Distance bin n:2376000 value:3741.143703553592
# Compute total distance min:2394000 max:2412000
# Distance bin n:2394000 value:2445.997287236555
# Compute total distance min:2412000 max:2430000
# Distance bin n:2412000 value:2874.6343889303807
# Compute total distance min:2430000 max:2448000
# Distance bin n:2430000 value:4016.063447912153
# Compute total distance min:2448000 max:2466000
# Distance bin n:2448000 value:2400.595969966853
# Compute total distance min:2466000 max:2484000
# Distance bin n:2466000 value:2808.8198730904987
# Compute total distance min:2484000 max:2502000
# Distance bin n:2484000 value:2571.29198308939
# Compute total distance min:2502000 max:2520000
# Distance bin n:2502000 value:1316.9900326259033
# Compute total distance min:2520000 max:2538000
# Distance bin n:2520000 value:698.24484522054
# Compute total distance min:2538000 max:2556000
# Distance bin n:2538000 value:918.2013360591166
# Compute total distance min:2556000 max:2574000
# Distance bin n:2556000 value:56.533424888070584
# Compute total distance min:2574000 max:2592000
# Distance bin n:2574000 value:0.0
# Compute total distance min:2592000 max:2610000
# Distance bin n:2592000 value:0.0
# Compute total distance min:2610000 max:2628000
# Distance bin n:2610000 value:0.0
# Compute total distance min:2628000 max:2646000
# Distance bin n:2628000 value:0.0
# Compute total distance min:2646000 max:2664000
# Distance bin n:2646000 value:283.334451241493
# Compute total distance min:2664000 max:2682000
# Distance bin n:2664000 value:14.252329011706207
# Compute total distance min:2682000 max:2700000
# Distance bin n:2682000 value:5618.282350118356
# Compute total distance min:2700000 max:2718000
# Distance bin n:2700000 value:500.74543406104294
# Compute total distance min:2718000 max:2736000
# Distance bin n:2718000 value:0.0
# Compute total distance min:2736000 max:2754000
# Distance bin n:2736000 value:0.0
# Compute total distance min:2754000 max:2772000
# Distance bin n:2754000 value:0.0
# Compute total distance min:2772000 max:2790000
# Distance bin n:2772000 value:850.1111407814755
# Compute total distance min:2790000 max:2808000
# Distance bin n:2790000 value:848.9832819622009
# Compute total distance min:2808000 max:2826000
# Distance bin n:2808000 value:896.0734049336347
# Compute total distance min:2826000 max:2844000
# Distance bin n:2826000 value:1417.024492093301
# Compute total distance min:2844000 max:2862000
# Distance bin n:2844000 value:312.3666295316886
# Compute total distance min:2862000 max:2880000
# Distance bin n:2862000 value:730.215801100054
# Compute total distance min:2880000 max:2898000
# Distance bin n:2880000 value:922.8722898678819
# Compute total distance min:2898000 max:2916000
# Distance bin n:2898000 value:1474.266931697541
# Compute total distance min:2916000 max:2934000
# Distance bin n:2916000 value:21.54184270642511
# Compute total distance min:2934000 max:2952000
# Distance bin n:2934000 value:0.0
# Compute total distance min:2952000 max:2970000
# Distance bin n:2952000 value:0.0
# Compute total distance min:2970000 max:2988000
# Distance bin n:2970000 value:80.26978988081922
# Compute total distance min:2988000 max:3006000
# Distance bin n:2988000 value:2696.848913245549
# Compute total distance min:3006000 max:3024000
# Distance bin n:3006000 value:8102.7590690837405
# Compute total distance min:3024000 max:3042000
# Distance bin n:3024000 value:0.0
# Compute total distance min:3042000 max:3060000
# Distance bin n:3042000 value:0.0
# Compute total distance min:3060000 max:3078000
# Distance bin n:3060000 value:0.0
# Compute total distance min:3078000 max:3096000
# Distance bin n:3078000 value:257.606370492677
# Compute total distance min:3096000 max:3114000
# Distance bin n:3096000 value:6448.0680087928695
# Compute total distance min:3114000 max:3132000
# Distance bin n:3114000 value:888.8470122505538
# Compute total distance min:3132000 max:3150000
# Distance bin n:3132000 value:0.0
# Compute total distance min:3150000 max:3168000
# Distance bin n:3150000 value:15.814344151873161
# Compute total distance min:3168000 max:3186000
# Distance bin n:3168000 value:394.4346758181363
# Compute total distance min:3186000 max:3204000
# Distance bin n:3186000 value:1753.6746727289672
# Compute total distance min:3204000 max:3222000
# Distance bin n:3204000 value:2174.252448217215
# Compute total distance min:3222000 max:3240000
# Distance bin n:3222000 value:1046.6958256978196
# Compute total distance min:3240000 max:3258000
# Distance bin n:3240000 value:723.1751987646197
# Compute total distance min:3258000 max:3276000
# Distance bin n:3258000 value:526.4353247039605
# Compute total distance min:3276000 max:3294000
# Distance bin n:3276000 value:2704.041399792709
# Compute total distance min:3294000 max:3312000
# Distance bin n:3294000 value:1985.908428663654
# Compute total distance min:3312000 max:3330000
# Distance bin n:3312000 value:1719.009117525274
# Compute total distance min:3330000 max:3348000
# Distance bin n:3330000 value:2616.5989240225013
# Compute total distance min:3348000 max:3366000
# Distance bin n:3348000 value:1477.9711535751208
# Compute total distance min:3366000 max:3384000
# Distance bin n:3366000 value:621.3546516920272
# Compute total distance min:3384000 max:3402000
# Distance bin n:3384000 value:667.3345103687517
# Compute total distance min:3402000 max:3420000
# Distance bin n:3402000 value:541.1345312147746
# Compute total distance min:3420000 max:3438000
# Distance bin n:3420000 value:391.7766078796847
# Compute total distance min:3438000 max:3456000
# Distance bin n:3438000 value:0.0
# Compute total distance min:3456000 max:3474000
# Distance bin n:3456000 value:0.0
# Compute total distance min:3474000 max:3492000
# Distance bin n:3474000 value:0.0
# Compute total distance min:3492000 max:3510000
# Distance bin n:3492000 value:8.223974617885863
# Compute total distance min:3510000 max:3528000
# Distance bin n:3510000 value:60.313220866620775
# Compute total distance min:3528000 max:3546000
# Distance bin n:3528000 value:831.8407591662469
# Compute total distance min:3546000 max:3564000
# Distance bin n:3546000 value:972.6441519251533
# Compute total distance min:3564000 max:3582000
# Distance bin n:3564000 value:233.8373735552006
# Compute total distance min:3582000 max:3600000
# Distance bin n:3582000 value:1108.6609825679968
# Compute total distance min:3600000 max:3618000
# Distance bin n:3600000 value:537.499925160697
# Compute total distance min:3618000 max:3636000
# Distance bin n:3618000 value:543.9811746852315
# Compute total distance min:3636000 max:3654000
# Distance bin n:3636000 value:548.4654939550461
# Compute total distance min:3654000 max:3672000
# Distance bin n:3654000 value:529.9971025726118
# Compute total distance min:3672000 max:3690000
# Distance bin n:3672000 value:1066.4700427825696
# Compute total distance min:3690000 max:3708000
# Distance bin n:3690000 value:1828.4682302586257
# Compute total distance min:3708000 max:3726000
# Distance bin n:3708000 value:2576.998857165226
# Compute total distance min:3726000 max:3744000
# Distance bin n:3726000 value:1550.7304915334587
# Compute total distance min:3744000 max:3762000
# Distance bin n:3744000 value:1488.442722941671
# Compute total distance min:3762000 max:3780000
# Distance bin n:3762000 value:794.9015404332602
# Compute total distance min:3780000 max:3798000
# Distance bin n:3780000 value:0.0
# Compute total distance min:3798000 max:3816000
# Distance bin n:3798000 value:0.0
# Compute total distance min:3816000 max:3834000
# Distance bin n:3816000 value:903.7838822333264
# Compute total distance min:3834000 max:3852000
# Distance bin n:3834000 value:2280.7969946483395
# Compute total distance min:3852000 max:3870000
# Distance bin n:3852000 value:2359.297214161304
# Compute total distance min:3870000 max:3888000
# Distance bin n:3870000 value:2601.5859258721875
# Compute total distance min:3888000 max:3906000
# Distance bin n:3888000 value:3025.660955362822
# Compute total distance min:3906000 max:3924000
# Distance bin n:3906000 value:3562.486035445055
# Compute total distance min:3924000 max:3942000
# Distance bin n:3924000 value:4257.368091937715
# Compute total distance min:3942000 max:3960000
# Distance bin n:3942000 value:3581.7205440824973
# Compute total distance min:3960000 max:3978000
# Distance bin n:3960000 value:3568.5893940071614
# Compute total distance min:3978000 max:3996000
# Distance bin n:3978000 value:3204.561663452316
# Compute total distance min:3996000 max:4014000
# Distance bin n:3996000 value:2681.7929013620146
# Compute total distance min:4014000 max:4032000
# Distance bin n:4014000 value:3122.128005035398
# Compute total distance min:4032000 max:4050000
# Distance bin n:4032000 value:3550.381178150862
# Compute total distance min:4050000 max:4068000
# Distance bin n:4050000 value:2834.2024976444736
# Compute total distance min:4068000 max:4086000
# Distance bin n:4068000 value:3597.8801308639913
# Compute total distance min:4086000 max:4104000
# Distance bin n:4086000 value:2281.1926730511627
# Compute total distance min:4104000 max:4122000
# Distance bin n:4104000 value:3096.0068230343604
# Compute total distance min:4122000 max:4140000
# Distance bin n:4122000 value:2796.7031874363665
# Compute total distance min:4140000 max:4158000
# Distance bin n:4140000 value:2551.089081302629
# Compute total distance min:4158000 max:4176000
# Distance bin n:4158000 value:2710.59972758566
# Compute total distance min:4176000 max:4194000
# Distance bin n:4176000 value:2983.308348064944
# Compute total distance min:4194000 max:4212000
# Distance bin n:4194000 value:2634.629636235262
# Compute total distance min:4212000 max:4230000
# Distance bin n:4212000 value:2040.931459839104
# Compute total distance min:4230000 max:4248000
# Distance bin n:4230000 value:2127.478995954107
# Compute total distance min:4248000 max:4266000
# Distance bin n:4248000 value:2554.9655960289037
# Compute total distance min:4266000 max:4284000
# Distance bin n:4266000 value:3524.2268594676752
# Compute total distance min:4284000 max:4302000
# Distance bin n:4284000 value:1676.2004915132904
# Compute total distance min:4302000 max:4320000
# Distance bin n:4302000 value:2588.3413018566202
# Compute total distance min:4320000 max:4338000
# Distance bin n:4320000 value:3850.2219678997903
# Compute total distance min:4338000 max:4356000
# Distance bin n:4338000 value:1951.7613253954942
# Compute total distance min:4356000 max:4374000
# Distance bin n:4356000 value:2470.7519120294146
# Compute total distance min:4374000 max:4392000
# Distance bin n:4374000 value:1786.887020399767
# Compute total distance min:4392000 max:4410000
# Distance bin n:4392000 value:723.8618297898017
# Compute total distance min:4410000 max:4428000
# Distance bin n:4410000 value:1461.0174789487612
# Compute total distance min:4428000 max:4446000
# Distance bin n:4428000 value:2843.721150235376
# Compute total distance min:4446000 max:4464000
# Distance bin n:4446000 value:3392.0065246443205
# Compute total distance min:4464000 max:4482000
# Distance bin n:4464000 value:3571.0040107317436
# Compute total distance min:4482000 max:4500000
# Distance bin n:4482000 value:2753.171252985617
# Compute total distance min:4500000 max:4518000
# Distance bin n:4500000 value:2811.2423233268282
# Compute total distance min:4518000 max:4536000
# Distance bin n:4518000 value:3423.816864218558
# Compute total distance min:4536000 max:4554000
# Distance bin n:4536000 value:4013.169874868512
# Compute total distance min:4554000 max:4572000
# Distance bin n:4554000 value:2835.633608116598
# Compute total distance min:4572000 max:4590000
# Distance bin n:4572000 value:3617.4332727000988
# Compute total distance min:4590000 max:4608000
# Distance bin n:4590000 value:3548.3569025430324
# Compute total distance min:4608000 max:4626000
# Distance bin n:4608000 value:3680.7829176700866
# Compute total distance min:4626000 max:4644000
# Distance bin n:4626000 value:2167.362055929803
# Compute total distance min:4644000 max:4662000
# Distance bin n:4644000 value:1950.3526452613341
# Compute total distance min:4662000 max:4680000
# Distance bin n:4662000 value:2841.6170636456104
# Compute total distance min:4680000 max:4698000
# Distance bin n:4680000 value:3543.7446251265033
# Compute total distance min:4698000 max:4716000
# Distance bin n:4698000 value:2513.322218383773
# Compute total distance min:4716000 max:4734000
# Distance bin n:4716000 value:1701.8485880126143
# Compute total distance min:4734000 max:4752000
# Distance bin n:4734000 value:1957.2831576663223
# Compute total distance min:4752000 max:4770000
# Distance bin n:4752000 value:2531.2077766419625
# Compute total distance min:4770000 max:4788000
# Distance bin n:4770000 value:3067.893904809766
# Compute total distance min:4788000 max:4806000
# Distance bin n:4788000 value:1343.1333506886922
# Compute total distance min:4806000 max:4824000
# Distance bin n:4806000 value:4817.078397354996
# Compute total distance min:4824000 max:4842000
# Distance bin n:4824000 value:1560.9506330276236
# Compute total distance min:4842000 max:4860000
# Distance bin n:4842000 value:4157.533420948141
# Compute total distance min:4860000 max:4878000
# Distance bin n:4860000 value:698.1135604304826
# Compute total distance min:4878000 max:4896000
# Distance bin n:4878000 value:1618.0671653953768
# Compute total distance min:4896000 max:4914000
# Distance bin n:4896000 value:634.1191991137285
# Compute total distance min:4914000 max:4932000
# Distance bin n:4914000 value:2138.1040094813748
# Compute total distance min:4932000 max:4950000
# Distance bin n:4932000 value:3034.0447766676693
# Compute total distance min:4950000 max:4968000
# Distance bin n:4950000 value:3012.170151475547
# Compute total distance min:4968000 max:4986000
# Distance bin n:4968000 value:3171.07909410665
# Compute total distance min:4986000 max:5004000
# Distance bin n:4986000 value:3768.7297705553806
# Compute total distance min:5004000 max:5022000
# Distance bin n:5004000 value:2978.3827902573375
# Compute total distance min:5022000 max:5040000
# Distance bin n:5022000 value:3321.1077706545307
# Compute total distance min:5040000 max:5058000
# Distance bin n:5040000 value:2261.125631088918
# Compute total distance min:5058000 max:5076000
# Distance bin n:5058000 value:2929.3357290517056
# Compute total distance min:5076000 max:5094000
# Distance bin n:5076000 value:3321.646940017886
# Compute total distance min:5094000 max:5112000
# Distance bin n:5094000 value:4306.676567626976
# Compute total distance min:5112000 max:5130000
# Distance bin n:5112000 value:4024.520262627091
# Compute total distance min:5130000 max:5148000
# Distance bin n:5130000 value:1805.4139250936742
# Compute total distance min:5148000 max:5166000
# Distance bin n:5148000 value:0.0
# Compute total distance min:5166000 max:5184000
# Distance bin n:5166000 value:0.0
# Compute total distance min:0 max:5184000
# 000022986408
# Compute total distance min:0 max:18000
# Distance bin n:0 value:6057.281024477113
# Compute total distance min:18000 max:36000
# Distance bin n:18000 value:5884.821636511145
# Compute total distance min:36000 max:54000
# Distance bin n:36000 value:4869.990749273556
# Compute total distance min:54000 max:72000
# Distance bin n:54000 value:4398.135105343814
# Compute total distance min:72000 max:90000
# Distance bin n:72000 value:4730.393141068784
# Compute total distance min:90000 max:108000
# Distance bin n:90000 value:4527.603306765551
# Compute total distance min:108000 max:126000
# Distance bin n:108000 value:4392.620477739905
# Compute total distance min:126000 max:144000
# Distance bin n:126000 value:3445.8720901674033
# Compute total distance min:144000 max:162000
# Distance bin n:144000 value:4375.10045239996
# Compute total distance min:162000 max:180000
# Distance bin n:162000 value:4142.581444720137
# Compute total distance min:180000 max:198000
# Distance bin n:180000 value:4156.340582619472
# Compute total distance min:198000 max:216000
# Distance bin n:198000 value:3762.5291447065724
# Compute total distance min:216000 max:234000
# Distance bin n:216000 value:3812.1629963713117
# Compute total distance min:234000 max:252000
# Distance bin n:234000 value:3702.356601604707
# Compute total distance min:252000 max:270000
# Distance bin n:252000 value:4047.0385512314497
# Compute total distance min:270000 max:288000
# Distance bin n:270000 value:3022.3063004351507
# Compute total distance min:288000 max:306000
# Distance bin n:288000 value:3631.452303300422
# Compute total distance min:306000 max:324000
# Distance bin n:306000 value:2096.244915350941
# Compute total distance min:324000 max:342000
# Distance bin n:324000 value:2029.06476627345
# Compute total distance min:342000 max:360000
# Distance bin n:342000 value:5719.22721356536
# Compute total distance min:360000 max:378000
# Distance bin n:360000 value:1308.3340815852791
# Compute total distance min:378000 max:396000
# Distance bin n:378000 value:2795.1422847726526
# Compute total distance min:396000 max:414000
# Distance bin n:396000 value:3021.77486222037
# Compute total distance min:414000 max:432000
# Distance bin n:414000 value:2341.7492057524896
# Compute total distance min:432000 max:450000
# Distance bin n:432000 value:503.4712359481459
# Compute total distance min:450000 max:468000
# Distance bin n:450000 value:3173.951626697188
# Compute total distance min:468000 max:486000
# Distance bin n:468000 value:2151.3307633273935
# Compute total distance min:486000 max:504000
# Distance bin n:486000 value:1390.4232670075007
# Compute total distance min:504000 max:522000
# Distance bin n:504000 value:964.5636996759376
# Compute total distance min:522000 max:540000
# Distance bin n:522000 value:2430.8997384801955
# Compute total distance min:540000 max:558000
# Distance bin n:540000 value:1294.5450527323535
# Compute total distance min:558000 max:576000
# Distance bin n:558000 value:19.638158829138916
# Compute total distance min:576000 max:594000
# Distance bin n:576000 value:1963.129738907308
# Compute total distance min:594000 max:612000
# Distance bin n:594000 value:1264.3376680523938
# Compute total distance min:612000 max:630000
# Distance bin n:612000 value:442.54148535289283
# Compute total distance min:630000 max:648000
# Distance bin n:630000 value:2799.0824000228713
# Compute total distance min:648000 max:666000
# Distance bin n:648000 value:1945.5754039979502
# Compute total distance min:666000 max:684000
# Distance bin n:666000 value:2780.7391202515155
# Compute total distance min:684000 max:702000
# Distance bin n:684000 value:1573.1334705038182
# Compute total distance min:702000 max:720000
# Distance bin n:702000 value:789.9095978656478
# Compute total distance min:720000 max:738000
# Distance bin n:720000 value:6483.878236237645
# Compute total distance min:738000 max:756000
# Distance bin n:738000 value:2659.354293274957
# Compute total distance min:756000 max:774000
# Distance bin n:756000 value:922.6394851444362
# Compute total distance min:774000 max:792000
# Distance bin n:774000 value:16.212992994148145
# Compute total distance min:792000 max:810000
# Distance bin n:792000 value:1961.8060589098652
# Compute total distance min:810000 max:828000
# Distance bin n:810000 value:1087.4905603109278
# Compute total distance min:828000 max:846000
# Distance bin n:828000 value:824.559357368477
# Compute total distance min:846000 max:864000
# Distance bin n:846000 value:0.0
# Compute total distance min:864000 max:882000
# Distance bin n:864000 value:0.0
# Compute total distance min:882000 max:900000
# Distance bin n:882000 value:0.0
# Compute total distance min:900000 max:918000
# Distance bin n:900000 value:0.0
# Compute total distance min:918000 max:936000
# Distance bin n:918000 value:5571.852490441964
# Compute total distance min:936000 max:954000
# Distance bin n:936000 value:3468.5478505399087
# Compute total distance min:954000 max:972000
# Distance bin n:954000 value:2915.903312279665
# Compute total distance min:972000 max:990000
# Distance bin n:972000 value:2137.4139478273546
# Compute total distance min:990000 max:1008000
# Distance bin n:990000 value:1798.2079542319784
# Compute total distance min:1008000 max:1026000
# Distance bin n:1008000 value:761.1919195219693
# Compute total distance min:1026000 max:1044000
# Distance bin n:1026000 value:1005.2290823761388
# Compute total distance min:1044000 max:1062000
# Distance bin n:1044000 value:1372.4720033452506
# Compute total distance min:1062000 max:1080000
# Distance bin n:1062000 value:4392.696715757009
# Compute total distance min:1080000 max:1098000
# Distance bin n:1080000 value:3511.6827060199653
# Compute total distance min:1098000 max:1116000
# Distance bin n:1098000 value:1930.6363643829216
# Compute total distance min:1116000 max:1134000
# Distance bin n:1116000 value:2660.5339361357856
# Compute total distance min:1134000 max:1152000
# Distance bin n:1134000 value:2832.706730979614
# Compute total distance min:1152000 max:1170000
# Distance bin n:1152000 value:367.89634274635864
# Compute total distance min:1170000 max:1188000
# Distance bin n:1170000 value:0.0
# Compute total distance min:1188000 max:1206000
# Distance bin n:1188000 value:52.18876879587446
# Compute total distance min:1206000 max:1224000
# Distance bin n:1206000 value:765.9651877172937
# Compute total distance min:1224000 max:1242000
# Distance bin n:1224000 value:382.8720320950119
# Compute total distance min:1242000 max:1260000
# Distance bin n:1242000 value:1137.9269088585502
# Compute total distance min:1260000 max:1278000
# Distance bin n:1260000 value:1150.873066185635
# Compute total distance min:1278000 max:1296000
# Distance bin n:1278000 value:167.07278268940127
# Compute total distance min:1296000 max:1314000
# Distance bin n:1296000 value:0.0
# Compute total distance min:1314000 max:1332000
# Distance bin n:1314000 value:1785.0346910298933
# Compute total distance min:1332000 max:1350000
# Distance bin n:1332000 value:5921.738918245732
# Compute total distance min:1350000 max:1368000
# Distance bin n:1350000 value:5614.090984037031
# Compute total distance min:1368000 max:1386000
# Distance bin n:1368000 value:5029.611989136087
# Compute total distance min:1386000 max:1404000
# Distance bin n:1386000 value:5281.528492928906
# Compute total distance min:1404000 max:1422000
# Distance bin n:1404000 value:4312.465666877224
# Compute total distance min:1422000 max:1440000
# Distance bin n:1422000 value:5146.203070946067
# Compute total distance min:1440000 max:1458000
# Distance bin n:1440000 value:4133.08486906004
# Compute total distance min:1458000 max:1476000
# Distance bin n:1458000 value:3970.320921642344
# Compute total distance min:1476000 max:1494000
# Distance bin n:1476000 value:2571.0390513737207
# Compute total distance min:1494000 max:1512000
# Distance bin n:1494000 value:1701.6195449373154
# Compute total distance min:1512000 max:1530000
# Distance bin n:1512000 value:4201.4881821810095
# Compute total distance min:1530000 max:1548000
# Distance bin n:1530000 value:3334.4632432033927
# Compute total distance min:1548000 max:1566000
# Distance bin n:1548000 value:4083.137183619444
# Compute total distance min:1566000 max:1584000
# Distance bin n:1566000 value:2737.139271869611
# Compute total distance min:1584000 max:1602000
# Distance bin n:1584000 value:1502.5037676963154
# Compute total distance min:1602000 max:1620000
# Distance bin n:1602000 value:3413.562699116007
# Compute total distance min:1620000 max:1638000
# Distance bin n:1620000 value:3094.107253173901
# Compute total distance min:1638000 max:1656000
# Distance bin n:1638000 value:2942.6848241207604
# Compute total distance min:1656000 max:1674000
# Distance bin n:1656000 value:888.2690359727538
# Compute total distance min:1674000 max:1692000
# Distance bin n:1674000 value:1403.6436773635041
# Compute total distance min:1692000 max:1710000
# Distance bin n:1692000 value:4384.963383787893
# Compute total distance min:1710000 max:1728000
# Distance bin n:1710000 value:3469.755371693894
# Compute total distance min:1728000 max:1746000
# Distance bin n:1728000 value:3361.4874363256345
# Compute total distance min:1746000 max:1764000
# Distance bin n:1746000 value:2797.8960293051314
# Compute total distance min:1764000 max:1782000
# Distance bin n:1764000 value:1069.9261760955167
# Compute total distance min:1782000 max:1800000
# Distance bin n:1782000 value:4183.725677244333
# Compute total distance min:1800000 max:1818000
# Distance bin n:1800000 value:3582.8774077898406
# Compute total distance min:1818000 max:1836000
# Distance bin n:1818000 value:2891.5625075417815
# Compute total distance min:1836000 max:1854000
# Distance bin n:1836000 value:2116.1328544066378
# Compute total distance min:1854000 max:1872000
# Distance bin n:1854000 value:551.9204082590419
# Compute total distance min:1872000 max:1890000
# Distance bin n:1872000 value:7.384401344675426
# Compute total distance min:1890000 max:1908000
# Distance bin n:1890000 value:0.0
# Compute total distance min:1908000 max:1926000
# Distance bin n:1908000 value:0.0
# Compute total distance min:1926000 max:1944000
# Distance bin n:1926000 value:6000.362681328593
# Compute total distance min:1944000 max:1962000
# Distance bin n:1944000 value:3432.713456431794
# Compute total distance min:1962000 max:1980000
# Distance bin n:1962000 value:3264.734904439204
# Compute total distance min:1980000 max:1998000
# Distance bin n:1980000 value:4444.494773054443
# Compute total distance min:1998000 max:2016000
# Distance bin n:1998000 value:2652.5463685601403
# Compute total distance min:2016000 max:2034000
# Distance bin n:2016000 value:2685.3301897825977
# Compute total distance min:2034000 max:2052000
# Distance bin n:2034000 value:3449.206803831069
# Compute total distance min:2052000 max:2070000
# Distance bin n:2052000 value:3038.152473564588
# Compute total distance min:2070000 max:2088000
# Distance bin n:2070000 value:2305.677647795111
# Compute total distance min:2088000 max:2106000
# Distance bin n:2088000 value:3105.14500749326
# Compute total distance min:2106000 max:2124000
# Distance bin n:2106000 value:743.8472600334642
# Compute total distance min:2124000 max:2142000
# Distance bin n:2124000 value:1694.2045982593324
# Compute total distance min:2142000 max:2160000
# Distance bin n:2142000 value:3139.5249458961134
# Compute total distance min:2160000 max:2178000
# Distance bin n:2160000 value:2681.9172895228257
# Compute total distance min:2178000 max:2196000
# Distance bin n:2178000 value:1809.756425297931
# Compute total distance min:2196000 max:2214000
# Distance bin n:2196000 value:3471.7899734387497
# Compute total distance min:2214000 max:2232000
# Distance bin n:2214000 value:1106.5869952964576
# Compute total distance min:2232000 max:2250000
# Distance bin n:2232000 value:3704.260406429894
# Compute total distance min:2250000 max:2268000
# Distance bin n:2250000 value:2955.267914704419
# Compute total distance min:2268000 max:2286000
# Distance bin n:2268000 value:2666.7753205223016
# Compute total distance min:2286000 max:2304000
# Distance bin n:2286000 value:4369.33987281043
# Compute total distance min:2304000 max:2322000
# Distance bin n:2304000 value:2978.6331531561177
# Compute total distance min:2322000 max:2340000
# Distance bin n:2322000 value:1582.9933162874536
# Compute total distance min:2340000 max:2358000
# Distance bin n:2340000 value:0.0
# Compute total distance min:2358000 max:2376000
# Distance bin n:2358000 value:31.495418393173182
# Compute total distance min:2376000 max:2394000
# Distance bin n:2376000 value:3678.55209953714
# Compute total distance min:2394000 max:2412000
# Distance bin n:2394000 value:3966.162136839363
# Compute total distance min:2412000 max:2430000
# Distance bin n:2412000 value:3703.1977881413663
# Compute total distance min:2430000 max:2448000
# Distance bin n:2430000 value:3680.031126729737
# Compute total distance min:2448000 max:2466000
# Distance bin n:2448000 value:1643.3472568165828
# Compute total distance min:2466000 max:2484000
# Distance bin n:2466000 value:3193.4063035697486
# Compute total distance min:2484000 max:2502000
# Distance bin n:2484000 value:1696.93019977684
# Compute total distance min:2502000 max:2520000
# Distance bin n:2502000 value:816.283927317827
# Compute total distance min:2520000 max:2538000
# Distance bin n:2520000 value:3228.980508024565
# Compute total distance min:2538000 max:2556000
# Distance bin n:2538000 value:4013.744676090947
# Compute total distance min:2556000 max:2574000
# Distance bin n:2556000 value:1881.0364359465743
# Compute total distance min:2574000 max:2592000
# Distance bin n:2574000 value:101.91981732439481
# Compute total distance min:2592000 max:2610000
# Distance bin n:2592000 value:0.0
# Compute total distance min:2610000 max:2628000
# Distance bin n:2610000 value:0.0
# Compute total distance min:2628000 max:2646000
# Distance bin n:2628000 value:0.0
# Compute total distance min:2646000 max:2664000
# Distance bin n:2646000 value:1.7640401163089416
# Compute total distance min:2664000 max:2682000
# Distance bin n:2664000 value:0.0
# Compute total distance min:2682000 max:2700000
# Distance bin n:2682000 value:5434.223350470882
# Compute total distance min:2700000 max:2718000
# Distance bin n:2700000 value:155.61980098346874
# Compute total distance min:2718000 max:2736000
# Distance bin n:2718000 value:495.0718627238547
# Compute total distance min:2736000 max:2754000
# Distance bin n:2736000 value:748.8193685632576
# Compute total distance min:2754000 max:2772000
# Distance bin n:2754000 value:208.1469229783769
# Compute total distance min:2772000 max:2790000
# Distance bin n:2772000 value:957.7682305592867
# Compute total distance min:2790000 max:2808000
# Distance bin n:2790000 value:843.5935533640205
# Compute total distance min:2808000 max:2826000
# Distance bin n:2808000 value:334.0828584026109
# Compute total distance min:2826000 max:2844000
# Distance bin n:2826000 value:865.60740952813
# Compute total distance min:2844000 max:2862000
# Distance bin n:2844000 value:210.6618912665422
# Compute total distance min:2862000 max:2880000
# Distance bin n:2862000 value:0.0
# Compute total distance min:2880000 max:2898000
# Distance bin n:2880000 value:122.95077142992444
# Compute total distance min:2898000 max:2916000
# Distance bin n:2898000 value:2375.564087306105
# Compute total distance min:2916000 max:2934000
# Distance bin n:2916000 value:204.2304281199896
# Compute total distance min:2934000 max:2952000
# Distance bin n:2934000 value:0.0
# Compute total distance min:2952000 max:2970000
# Distance bin n:2952000 value:0.0
# Compute total distance min:2970000 max:2988000
# Distance bin n:2970000 value:0.0
# Compute total distance min:2988000 max:3006000
# Distance bin n:2988000 value:0.0
# Compute total distance min:3006000 max:3024000
# Distance bin n:3006000 value:809.1257879249249
# Compute total distance min:3024000 max:3042000
# Distance bin n:3024000 value:0.0
# Compute total distance min:3042000 max:3060000
# Distance bin n:3042000 value:0.0
# Compute total distance min:3060000 max:3078000
# Distance bin n:3060000 value:0.0
# Compute total distance min:3078000 max:3096000
# Distance bin n:3078000 value:225.25665813958494
# Compute total distance min:3096000 max:3114000
# Distance bin n:3096000 value:2316.7673603858902
# Compute total distance min:3114000 max:3132000
# Distance bin n:3114000 value:180.75010637496396
# Compute total distance min:3132000 max:3150000
# Distance bin n:3132000 value:0.0
# Compute total distance min:3150000 max:3168000
# Distance bin n:3150000 value:462.30306742316384
# Compute total distance min:3168000 max:3186000
# Distance bin n:3168000 value:319.6350999877362
# Compute total distance min:3186000 max:3204000
# Distance bin n:3186000 value:864.6448428847032
# Compute total distance min:3204000 max:3222000
# Distance bin n:3204000 value:1270.9441315936012
# Compute total distance min:3222000 max:3240000
# Distance bin n:3222000 value:2040.3725028872764
# Compute total distance min:3240000 max:3258000
# Distance bin n:3240000 value:1086.028904977212
# Compute total distance min:3258000 max:3276000
# Distance bin n:3258000 value:2229.333056386797
# Compute total distance min:3276000 max:3294000
# Distance bin n:3276000 value:2508.0066961317584
# Compute total distance min:3294000 max:3312000
# Distance bin n:3294000 value:2315.476393058451
# Compute total distance min:3312000 max:3330000
# Distance bin n:3312000 value:3190.369285949723
# Compute total distance min:3330000 max:3348000
# Distance bin n:3330000 value:2964.9947100312297
# Compute total distance min:3348000 max:3366000
# Distance bin n:3348000 value:1189.9740244546317
# Compute total distance min:3366000 max:3384000
# Distance bin n:3366000 value:870.0445807417292
# Compute total distance min:3384000 max:3402000
# Distance bin n:3384000 value:182.0640041813091
# Compute total distance min:3402000 max:3420000
# Distance bin n:3402000 value:8.977897067603141
# Compute total distance min:3420000 max:3438000
# Distance bin n:3420000 value:36.122247408561265
# Compute total distance min:3438000 max:3456000
# Distance bin n:3438000 value:131.58737855669307
# Compute total distance min:3456000 max:3474000
# Distance bin n:3456000 value:785.4206834776112
# Compute total distance min:3474000 max:3492000
# Distance bin n:3474000 value:6.449990997868296
# Compute total distance min:3492000 max:3510000
# Distance bin n:3492000 value:449.1922039097085
# Compute total distance min:3510000 max:3528000
# Distance bin n:3510000 value:512.7997546733873
# Compute total distance min:3528000 max:3546000
# Distance bin n:3528000 value:981.7795781848845
# Compute total distance min:3546000 max:3564000
# Distance bin n:3546000 value:522.8104409038561
# Compute total distance min:3564000 max:3582000
# Distance bin n:3564000 value:964.0989230296549
# Compute total distance min:3582000 max:3600000
# Distance bin n:3582000 value:511.9411461741355
# Compute total distance min:3600000 max:3618000
# Distance bin n:3600000 value:597.8181874046011
# Compute total distance min:3618000 max:3636000
# ...
# Distance bin n:2214000 value:2375.0028778616393
# Compute total distance min:2232000 max:2250000
# Distance bin n:2232000 value:3588.006418823782
# Compute total distance min:2250000 max:2268000
# Distance bin n:2250000 value:2964.1798730833984
# Compute total distance min:2268000 max:2286000
# Distance bin n:2268000 value:3328.7411512294534
# Compute total distance min:2286000 max:2304000
# Distance bin n:2286000 value:4164.885293584278
# Compute total distance min:2304000 max:2322000
# Distance bin n:2304000 value:1883.0105898768932
# Compute total distance min:2322000 max:2340000
# Distance bin n:2322000 value:3319.1811724993167
# Compute total distance min:2340000 max:2358000
# Distance bin n:2340000 value:11422.112220445963
# Compute total distance min:2358000 max:2376000
# Distance bin n:2358000 value:1098.3530095007595
# Compute total distance min:2376000 max:2394000
# Distance bin n:2376000 value:3347.8425237988963
# Compute total distance min:2394000 max:2412000
# Distance bin n:2394000 value:2925.732042194399
# Compute total distance min:2412000 max:2430000
# Distance bin n:2412000 value:2736.3115417338595
# Compute total distance min:2430000 max:2448000
# Distance bin n:2430000 value:3613.2109438856733
# Compute total distance min:2448000 max:2466000
# Distance bin n:2448000 value:2294.5034022940226
# Compute total distance min:2466000 max:2484000
# Distance bin n:2466000 value:2565.264120836301
# Compute total distance min:2484000 max:2502000
# Distance bin n:2484000 value:2264.607275137088
# Compute total distance min:2502000 max:2520000
# Distance bin n:2502000 value:1332.3719766855747
# Compute total distance min:2520000 max:2538000
# Distance bin n:2520000 value:1151.4596037523518
# Compute total distance min:2538000 max:2556000
# Distance bin n:2538000 value:1891.4713777527363
# Compute total distance min:2556000 max:2574000
# Distance bin n:2556000 value:735.5227983967534
# Compute total distance min:2574000 max:2592000
# Distance bin n:2574000 value:870.4560971954771
# Compute total distance min:2592000 max:2610000
# Distance bin n:2592000 value:75.96961740335337
# Compute total distance min:2610000 max:2628000
# Distance bin n:2610000 value:2.5127686929304267
# Compute total distance min:2628000 max:2646000
# Distance bin n:2628000 value:0.0
# Compute total distance min:2646000 max:2664000
# Distance bin n:2646000 value:0.0
# Compute total distance min:2664000 max:2682000
# Distance bin n:2664000 value:0.0
# Compute total distance min:2682000 max:2700000
# Distance bin n:2682000 value:9.434083068926004
# Compute total distance min:2700000 max:2718000
# Distance bin n:2700000 value:0.9119884614403785
# Compute total distance min:2718000 max:2736000
# Distance bin n:2718000 value:0.0
# Compute total distance min:2736000 max:2754000
# Distance bin n:2736000 value:0.0
# Compute total distance min:2754000 max:2772000
# Distance bin n:2754000 value:252.065149780869
# Compute total distance min:2772000 max:2790000
# Distance bin n:2772000 value:1861.335278436007
# Compute total distance min:2790000 max:2808000
# Distance bin n:2790000 value:2237.7770651042833
# Compute total distance min:2808000 max:2826000
# Distance bin n:2808000 value:1813.4772305761383
# Compute total distance min:2826000 max:2844000
# Distance bin n:2826000 value:3124.783663432397
# Compute total distance min:2844000 max:2862000
# Distance bin n:2844000 value:1086.9320099259269
# Compute total distance min:2862000 max:2880000
# Distance bin n:2862000 value:0.0
# Compute total distance min:2880000 max:2898000
# Distance bin n:2880000 value:236.61504528571092
# Compute total distance min:2898000 max:2916000
# Distance bin n:2898000 value:808.4529872208727
# Compute total distance min:2916000 max:2934000
# Distance bin n:2916000 value:1649.9582481066286
# Compute total distance min:2934000 max:2952000
# Distance bin n:2934000 value:314.43124730862513
# Compute total distance min:2952000 max:2970000
# Distance bin n:2952000 value:0.0
# Compute total distance min:2970000 max:2988000
# Distance bin n:2970000 value:0.0
# Compute total distance min:2988000 max:3006000
# Distance bin n:2988000 value:0.0
# Compute total distance min:3006000 max:3024000
# Distance bin n:3006000 value:3670.395942250634
# Compute total distance min:3024000 max:3042000
# Distance bin n:3024000 value:0.0
# Compute total distance min:3042000 max:3060000
# Distance bin n:3042000 value:0.0
# Compute total distance min:3060000 max:3078000
# Distance bin n:3060000 value:1044.498037342537
# Compute total distance min:3078000 max:3096000
# Distance bin n:3078000 value:2518.0299461814257
# Compute total distance min:3096000 max:3114000
# Distance bin n:3096000 value:2404.5568509411314
# Compute total distance min:3114000 max:3132000
# Distance bin n:3114000 value:666.4030698382496
# Compute total distance min:3132000 max:3150000
# Distance bin n:3132000 value:827.4117895632339
# Compute total distance min:3150000 max:3168000
# Distance bin n:3150000 value:543.1595254837032
# Compute total distance min:3168000 max:3186000
# Distance bin n:3168000 value:466.2156672158235
# Compute total distance min:3186000 max:3204000
# Distance bin n:3186000 value:1177.3394719987516
# Compute total distance min:3204000 max:3222000
# Distance bin n:3204000 value:1513.3757771240641
# Compute total distance min:3222000 max:3240000
# Distance bin n:3222000 value:1048.247084851196
# Compute total distance min:3240000 max:3258000
# Distance bin n:3240000 value:1868.3091038955122
# Compute total distance min:3258000 max:3276000
# Distance bin n:3258000 value:1059.0983719862027
# Compute total distance min:3276000 max:3294000
# Distance bin n:3276000 value:3038.635802068754
# Compute total distance min:3294000 max:3312000
# Distance bin n:3294000 value:2615.855889501189
# Compute total distance min:3312000 max:3330000
# Distance bin n:3312000 value:1824.7757811666424
# Compute total distance min:3330000 max:3348000
# Distance bin n:3330000 value:2798.6767319597016
# Compute total distance min:3348000 max:3366000
# Distance bin n:3348000 value:1792.6311433522233
# Compute total distance min:3366000 max:3384000
# Distance bin n:3366000 value:752.7530422404324
# Compute total distance min:3384000 max:3402000
# Distance bin n:3384000 value:19.900945125239463
# Compute total distance min:3402000 max:3420000
# Distance bin n:3402000 value:0.0
# Compute total distance min:3420000 max:3438000
# Distance bin n:3420000 value:131.78942664208265
# Compute total distance min:3438000 max:3456000
# Distance bin n:3438000 value:521.9840278850799
# Compute total distance min:3456000 max:3474000
# Distance bin n:3456000 value:508.56776658828045
# Compute total distance min:3474000 max:3492000
# Distance bin n:3474000 value:469.30044064215457
# Compute total distance min:3492000 max:3510000
# Distance bin n:3492000 value:1085.83512156219
# Compute total distance min:3510000 max:3528000
# Distance bin n:3510000 value:582.090528490531
# Compute total distance min:3528000 max:3546000
# Distance bin n:3528000 value:960.2849237146356
# Compute total distance min:3546000 max:3564000
# Distance bin n:3546000 value:425.48869322916136
# Compute total distance min:3564000 max:3582000
# Distance bin n:3564000 value:0.0
# Compute total distance min:3582000 max:3600000
# Distance bin n:3582000 value:0.0
# Compute total distance min:3600000 max:3618000
# Distance bin n:3600000 value:0.0
# Compute total distance min:3618000 max:3636000
# Distance bin n:3618000 value:3.3723764769937925
# Compute total distance min:3636000 max:3654000
# Distance bin n:3636000 value:0.0
# Compute total distance min:3654000 max:3672000
# Distance bin n:3654000 value:68.625892515097
# Compute total distance min:3672000 max:3690000
# Distance bin n:3672000 value:841.6727654062296
# Compute total distance min:3690000 max:3708000
# Distance bin n:3690000 value:1738.8320017426672
# Compute total distance min:3708000 max:3726000
# Distance bin n:3708000 value:1853.5569004071212
# Compute total distance min:3726000 max:3744000
# Distance bin n:3726000 value:1066.475596990041
# Compute total distance min:3744000 max:3762000
# Distance bin n:3744000 value:1485.3829990077788
# Compute total distance min:3762000 max:3780000
# Distance bin n:3762000 value:994.571300252421
# Compute total distance min:3780000 max:3798000
# Distance bin n:3780000 value:0.0
# Compute total distance min:3798000 max:3816000
# Distance bin n:3798000 value:243.26513438759582
# Compute total distance min:3816000 max:3834000
# Distance bin n:3816000 value:2484.131281717699
# Compute total distance min:3834000 max:3852000
# Distance bin n:3834000 value:3476.189503905717
# Compute total distance min:3852000 max:3870000
# Distance bin n:3852000 value:3593.3252959592796
# Compute total distance min:3870000 max:3888000
# Distance bin n:3870000 value:2376.3334516339673
# Compute total distance min:3888000 max:3906000
# Distance bin n:3888000 value:3239.294919578934
# Compute total distance min:3906000 max:3924000
# Distance bin n:3906000 value:3920.9732852199018
# Compute total distance min:3924000 max:3942000
# Distance bin n:3924000 value:3647.316522807851
# Compute total distance min:3942000 max:3960000
# Distance bin n:3942000 value:3424.798393691324
# Compute total distance min:3960000 max:3978000
# Distance bin n:3960000 value:3878.1012747426544
# Compute total distance min:3978000 max:3996000
# Distance bin n:3978000 value:3088.7883348168375
# Compute total distance min:3996000 max:4014000
# Distance bin n:3996000 value:2743.5690458197346
# Compute total distance min:4014000 max:4032000
# Distance bin n:4014000 value:3253.6918342416675
# Compute total distance min:4032000 max:4050000
# Distance bin n:4032000 value:3825.8677913399533
# Compute total distance min:4050000 max:4068000
# Distance bin n:4050000 value:3590.512693964402
# Compute total distance min:4068000 max:4086000
# Distance bin n:4068000 value:4107.992757817583
# Compute total distance min:4086000 max:4104000
# Distance bin n:4086000 value:3145.503082215076
# Compute total distance min:4104000 max:4122000
# Distance bin n:4104000 value:3104.6206265094793
# Compute total distance min:4122000 max:4140000
# Distance bin n:4122000 value:2439.9371970002253
# Compute total distance min:4140000 max:4158000
# Distance bin n:4140000 value:2997.451660112056
# Compute total distance min:4158000 max:4176000
# Distance bin n:4158000 value:2833.912484190634
# Compute total distance min:4176000 max:4194000
# Distance bin n:4176000 value:3155.5648728864157
# Compute total distance min:4194000 max:4212000
# Distance bin n:4194000 value:3078.3963210730367
# Compute total distance min:4212000 max:4230000
# Distance bin n:4212000 value:2189.5319028625104
# Compute total distance min:4230000 max:4248000
# Distance bin n:4230000 value:2850.43740221269
# Compute total distance min:4248000 max:4266000
# Distance bin n:4248000 value:3058.9895626946163
# Compute total distance min:4266000 max:4284000
# Distance bin n:4266000 value:4278.507375092454
# Compute total distance min:4284000 max:4302000
# Distance bin n:4284000 value:847.5657508521311
# Compute total distance min:4302000 max:4320000
# Distance bin n:4302000 value:2567.0175569052303
# Compute total distance min:4320000 max:4338000
# Distance bin n:4320000 value:2973.0525072595096
# Compute total distance min:4338000 max:4356000
# Distance bin n:4338000 value:2081.309224203176
# Compute total distance min:4356000 max:4374000
# Distance bin n:4356000 value:2714.555637612833
# Compute total distance min:4374000 max:4392000
# Distance bin n:4374000 value:2239.9403685719044
# Compute total distance min:4392000 max:4410000
# Distance bin n:4392000 value:1162.7913804701798
# Compute total distance min:4410000 max:4428000
# Distance bin n:4410000 value:1651.5250349241671
# Compute total distance min:4428000 max:4446000
# Distance bin n:4428000 value:2934.5922057173093
# Compute total distance min:4446000 max:4464000
# Distance bin n:4446000 value:3502.6044314655774
# Compute total distance min:4464000 max:4482000
# Distance bin n:4464000 value:3315.8962732716204
# Compute total distance min:4482000 max:4500000
# Distance bin n:4482000 value:3025.0470525131564
# Compute total distance min:4500000 max:4518000
# Distance bin n:4500000 value:3313.757991732814
# Compute total distance min:4518000 max:4536000
# Distance bin n:4518000 value:3115.817881491289
# Compute total distance min:4536000 max:4554000
# Distance bin n:4536000 value:4085.8602023441963
# Compute total distance min:4554000 max:4572000
# Distance bin n:4554000 value:3571.4048707059073
# Compute total distance min:4572000 max:4590000
# Distance bin n:4572000 value:3488.309254486574
# Compute total distance min:4590000 max:4608000
# Distance bin n:4590000 value:4500.170207418835
# Compute total distance min:4608000 max:4626000
# Distance bin n:4608000 value:2947.4118063467827
# Compute total distance min:4626000 max:4644000
# Distance bin n:4626000 value:2478.993372535886
# Compute total distance min:4644000 max:4662000
# Distance bin n:4644000 value:3430.6804436796087
# Compute total distance min:4662000 max:4680000
# Distance bin n:4662000 value:2719.6655193815595
# Compute total distance min:4680000 max:4698000
# Distance bin n:4680000 value:4486.687601680803
# Compute total distance min:4698000 max:4716000
# Distance bin n:4698000 value:3895.6526842115504
# Compute total distance min:4716000 max:4734000
# Distance bin n:4716000 value:3246.101588649372
# Compute total distance min:4734000 max:4752000
# Distance bin n:4734000 value:2369.315810710748
# Compute total distance min:4752000 max:4770000
# Distance bin n:4752000 value:3018.379578184238
# Compute total distance min:4770000 max:4788000
# Distance bin n:4770000 value:2232.49711646187
# Compute total distance min:4788000 max:4806000
# Distance bin n:4788000 value:2300.437130061431
# Compute total distance min:4806000 max:4824000
# Distance bin n:4806000 value:3274.421090670236
# Compute total distance min:4824000 max:4842000
# Distance bin n:4824000 value:2110.506113820127
# Compute total distance min:4842000 max:4860000
# Distance bin n:4842000 value:3673.0493088820913
# Compute total distance min:4860000 max:4878000
# Distance bin n:4860000 value:411.3172845154617
# Compute total distance min:4878000 max:4896000
# Distance bin n:4878000 value:2304.6721872903995
# Compute total distance min:4896000 max:4914000
# Distance bin n:4896000 value:1134.837390370687
# Compute total distance min:4914000 max:4932000
# Distance bin n:4914000 value:1406.6830206619281
# Compute total distance min:4932000 max:4950000
# Distance bin n:4932000 value:2679.9028597219867
# Compute total distance min:4950000 max:4968000
# Distance bin n:4950000 value:2797.1466797676926
# Compute total distance min:4968000 max:4986000
# Distance bin n:4968000 value:3476.0005397338596
# Compute total distance min:4986000 max:5004000
# Distance bin n:4986000 value:3412.9190202410423
# Compute total distance min:5004000 max:5022000
# Distance bin n:5004000 value:2782.637444577416
# Compute total distance min:5022000 max:5040000
# Distance bin n:5022000 value:3091.3995619790976
# Compute total distance min:5040000 max:5058000
# Distance bin n:5040000 value:2500.6947697434352
# Compute total distance min:5058000 max:5076000
# Distance bin n:5058000 value:2450.32923513903
# Compute total distance min:5076000 max:5094000
# Distance bin n:5076000 value:3194.0279206172545
# Compute total distance min:5094000 max:5112000
# Distance bin n:5094000 value:3469.5410231788605
# Compute total distance min:5112000 max:5130000
# Distance bin n:5112000 value:4880.858066937446
# Compute total distance min:5130000 max:5148000
# Distance bin n:5130000 value:2345.809071999976
# Compute total distance min:5148000 max:5166000
# Distance bin n:5148000 value:0.0
# Compute total distance min:5166000 max:5184000
# Distance bin n:5166000 value:0.0
# Compute total distance min:0 max:5184000
# 288
# 288
# 000022986492
# 000022986408
# 000022986409
# 000022986416
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7d6b992ce741> in <module>
#     139     lineData = []
#     140
# --> 141     for eventList in groupTimeLine["all"].eventList:
#     142         lineData.append( ( eventList.startFrame-addThickness , eventList.duration()+addThickness ))
#     143
#
# NameError: name 'groupTimeLine' is not defined
