# %%
import sys
sys.path.insert(1, "../")

import sqlite3
from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
from lmtanalysis import BuildEventTrain3, BuildEventTrain4, BuildEventTrain2, BuildEventFollowZone, BuildEventRear5, BuildEventFloorSniffing,\
    BuildEventSocialApproach, BuildEventSocialEscape, BuildEventApproachContact,BuildEventOralOralContact,\
    BuildEventApproachRear, BuildEventGroup2, BuildEventGroup3, BuildEventGroup4, BuildEventOralGenitalContact, \
    BuildEventStop, BuildEventWaterPoint, \
    BuildEventMove, BuildEventGroup3MakeBreak, BuildEventGroup4MakeBreak,\
    BuildEventSideBySide, BuildEventSideBySideOpposite, BuildEventDetection,\
    BuildDataBaseIndex, BuildEventWallJump, BuildEventSAP,\
    BuildEventOralSideSequence
    
import lmtanalysis, sys
from tkinter.filedialog import askopenfilename


def process( files, eventName ):

    for file in files:
    
        print(file)
        connection = sqlite3.connect( file )        

        pool = AnimalPool( )
        pool.loadAnimals( connection )
    
        event= {}
        
        for idAnimalA in pool.animalDictionnary.keys():
                                    
            for idAnimalB in pool.animalDictionnary.keys():
                
                event[idAnimalA, idAnimalB] = EventTimeLine( connection, eventName, idAnimalA, idAnimalB )
                
            
                
        for idAnimalA in pool.animalDictionnary.keys():
            
            txt = str(idAnimalA) + ":" + str( pool.animalDictionnary[idAnimalA]) + "\t" 
                                                
            for idAnimalB in pool.animalDictionnary.keys():
                
                txt += str( len( event[idAnimalA, idAnimalB].getEventList() ) ) + "\t"

            print( txt )

        
    print( "*** DONE ***")

def getAllEvents( file ):
    print( "Loading events...")
    connection = sqlite3.connect( file )
    query = "select name from event group by name"
    c = connection.cursor()     
    c.execute( query )    
    all_rows = c.fetchall()        
    header = [ "Name" ]
    data =[]    
    for row in all_rows:
        data.append( row[0] )
    return data

if __name__ == '__main__':
    
    print("Code launched.")
    
    
    files = askopenfilename( title="Choose a set of file to process", multiple=1 )

    eventList = getAllEvents( files[0] )    

    for i in range( 0 , len( eventList) ):
        print( "[" + str( i ) + "] :" + eventList[i] )
    
    while( True ):
        
        userInput = input ("Event to read (full name or number ) (enter to quit): ")
        
        if userInput=="":
            print("Exit :)")
            quit()
        
        if ( userInput.isdigit() ):
            eventName = eventList[ int( userInput )]
        else:
            eventName = userInput
        
        process( files, eventName )
# Out:
# Code launched.
# Loading events...
# [0] :Approach
# [1] :Approach contact
# [2] :Approach rear
# [3] :Break contact
# [4] :Contact
# [5] :Detection
# [6] :FollowZone Isolated
# [7] :Get away
# [8] :Group 3 break
# [9] :Group 3 make
# [10] :Group 4 break
# [11] :Group 4 make
# [12] :Group2
# [13] :Group3
# [14] :Group4
# [15] :Head detected
# [16] :Look down
# [17] :MACHINE LEARNING ASSOCIATION
# [18] :Move
# [19] :Move in contact
# [20] :Move isolated
# [21] :Nest4_
# [22] :Oral-genital Contact
# [23] :Oral-oral Contact
# [24] :RFID ASSIGN ANONYMOUS TRACK
# [25] :RFID MATCH
# [26] :RFID MISMATCH
# [27] :Rear in contact
# [28] :Rear isolated
# [29] :Rearing
# [30] :SAP
# [31] :Side by side Contact
# [32] :Side by side Contact, opposite way
# [33] :Social approach
# [34] :Social escape
# [35] :Stop
# [36] :Stop in contact
# [37] :Stop isolated
# [38] :Train2
# [39] :Train3
# [40] :WallJump
# [41] :Water Zone
# [42] :night
# [43] :seq oral geni - oral oral
# [44] :seq oral oral - oral genital
# Event to read (full name or number ) (enter to quit): 4
# D:/live mouse tracker data/data/Experiment 21/Experiment 21.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None
# Animal Id:3 Name:C RFID:000022986416 Genotype:HT User1:None
# Animal Id:2 Name:B RFID:000022986562 Genotype:WT User1:None
# Animal Id:4 Name:D RFID:000022986387 Genotype:WT User1:None
# Contact  Id( 1 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4973375797271729 S )
# Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 9667  records loaded in  1.593360424041748 S )
# Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 9216  records loaded in  1.6113641262054443 S )
# Contact  Id( 1 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 10007  records loaded in  1.61836576461792 S )
# Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 9667  records loaded in  1.6838891506195068 S )
# Contact  Id( 3 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.496337652206421 S )
# Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 9499  records loaded in  1.7063865661621094 S )
# Contact  Id( 3 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 9862  records loaded in  1.6313679218292236 S )
# Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 9216  records loaded in  1.6273677349090576 S )
# Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 9499  records loaded in  1.6013617515563965 S )
# Contact  Id( 2 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.497337818145752 S )
# Contact  Id( 2 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 11014  records loaded in  1.6383705139160156 S )
# Contact  Id( 4 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 10008  records loaded in  1.6643760204315186 S )
# Contact  Id( 4 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 9862  records loaded in  1.632368803024292 S )
# Contact  Id( 4 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 11015  records loaded in  1.6383697986602783 S )
# Contact  Id( 4 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5043396949768066 S )
# 1:Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None	0	9667	9216	10007
# 3:Animal Id:3 Name:C RFID:000022986416 Genotype:HT User1:None	9667	0	9499	9862
# 2:Animal Id:2 Name:B RFID:000022986562 Genotype:WT User1:None	9216	9499	0	11014
# 4:Animal Id:4 Name:D RFID:000022986387 Genotype:WT User1:None	10008	9862	11015	0
# *** DONE ***
# Event to read (full name or number ) (enter to quit): 19
# D:/live mouse tracker data/data/Experiment 21/Experiment 21.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None
# Animal Id:3 Name:C RFID:000022986416 Genotype:HT User1:None
# Animal Id:2 Name:B RFID:000022986562 Genotype:WT User1:None
# Animal Id:4 Name:D RFID:000022986387 Genotype:WT User1:None
# Move in contact  Id( 1 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5103485584259033 S )
# Move in contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5053398609161377 S )
# Move in contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4883360862731934 S )
# Move in contact  Id( 1 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5063323974609375 S )
# Move in contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.532346487045288 S )
# Move in contact  Id( 3 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5103490352630615 S )
# Move in contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5163342952728271 S )
# Move in contact  Id( 3 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.513350248336792 S )
# Move in contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5223355293273926 S )
# Move in contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5203521251678467 S )
# Move in contact  Id( 2 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5143420696258545 S )
# Move in contact  Id( 2 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5113415718078613 S )
# Move in contact  Id( 4 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5173344612121582 S )
# Move in contact  Id( 4 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5183429718017578 S )
# Move in contact  Id( 4 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5113499164581299 S )
# Move in contact  Id( 4 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5103414058685303 S )
# 1:Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None	0	0	0	0
# 3:Animal Id:3 Name:C RFID:000022986416 Genotype:HT User1:None	0	0	0	0
# 2:Animal Id:2 Name:B RFID:000022986562 Genotype:WT User1:None	0	0	0	0
# 4:Animal Id:4 Name:D RFID:000022986387 Genotype:WT User1:None	0	0	0	0
# *** DONE ***
# Event to read (full name or number ) (enter to quit): 0
# D:/live mouse tracker data/data/Experiment 21/Experiment 21.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None
# Animal Id:3 Name:C RFID:000022986416 Genotype:HT User1:None
# Animal Id:2 Name:B RFID:000022986562 Genotype:WT User1:None
# Animal Id:4 Name:D RFID:000022986387 Genotype:WT User1:None
# Approach  Id( 1 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.558351993560791 S )
# Approach  Id( 1 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 106196  records loaded in  2.107476234436035 S )
# Approach  Id( 1 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 112286  records loaded in  2.168489933013916 S )
# Approach  Id( 1 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 114376  records loaded in  2.1824851036071777 S )
# Approach  Id( 3 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 111026  records loaded in  2.135491132736206 S )
# Approach  Id( 3 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5623528957366943 S )
# Approach  Id( 3 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 108916  records loaded in  2.135483980178833 S )
# Approach  Id( 3 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 114162  records loaded in  2.0374627113342285 S )
# Approach  Id( 2 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 107223  records loaded in  2.155489921569824 S )
# Approach  Id( 2 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 99567  records loaded in  1.9764463901519775 S )
# Approach  Id( 2 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5783483982086182 S )
# Approach  Id( 2 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 112414  records loaded in  2.2185120582580566 S )
# Approach  Id( 4 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 104499  records loaded in  1.9884414672851562 S )
# Approach  Id( 4 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 101560  records loaded in  2.214492082595825 S )
# Approach  Id( 4 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 105516  records loaded in  2.003443956375122 S )
# Approach  Id( 4 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5783653259277344 S )
# 1:Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None	0	106196	112286	114376
# 3:Animal Id:3 Name:C RFID:000022986416 Genotype:HT User1:None	111026	0	108916	114162
# 2:Animal Id:2 Name:B RFID:000022986562 Genotype:WT User1:None	107223	99567	0	112414
# 4:Animal Id:4 Name:D RFID:000022986387 Genotype:WT User1:None	104499	101560	105516	0
# *** DONE ***
# Event to read (full name or number ) (enter to quit):
# Exit :)
# D:/live mouse tracker data/data/Experiment 21/Experiment 21.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None
# Animal Id:3 Name:C RFID:000022986416 Genotype:HT User1:None
# Animal Id:2 Name:B RFID:000022986562 Genotype:WT User1:None
# Animal Id:4 Name:D RFID:000022986387 Genotype:WT User1:None
#   Id( 1 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5044326782226562 S )
#   Id( 1 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4933114051818848 S )
#   Id( 1 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.492262363433838 S )
#   Id( 1 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.484457015991211 S )
#   Id( 3 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4938764572143555 S )
#   Id( 3 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.490379810333252 S )
#   Id( 3 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4824504852294922 S )
#   Id( 3 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4725408554077148 S )
#   Id( 2 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4877598285675049 S )
#   Id( 2 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4635505676269531 S )
#   Id( 2 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4841816425323486 S )
#   Id( 2 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4847028255462646 S )
#   Id( 4 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4686641693115234 S )
#   Id( 4 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4843497276306152 S )
#   Id( 4 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4717037677764893 S )
#   Id( 4 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.5003132820129395 S )
# 1:Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None	0	0	0	0
# 3:Animal Id:3 Name:C RFID:000022986416 Genotype:HT User1:None	0	0	0	0
# 2:Animal Id:2 Name:B RFID:000022986562 Genotype:WT User1:None	0	0	0	0
# 4:Animal Id:4 Name:D RFID:000022986387 Genotype:WT User1:None	0	0	0	0
# *** DONE ***
# Event to read (full name or number ) (enter to quit):
# Exit :)
# D:/live mouse tracker data/data/Experiment 21/Experiment 21.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000022986492 Genotype:HT User1:None
# Animal Id:3 Name:C RFID:000022986416 Genotype:HT User1:None
# Animal Id:2 Name:B RFID:000022986562 Genotype:WT User1:None
# Animal Id:4 Name:D RFID:000022986387 Genotype:WT User1:None
#   Id( 1 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4737718105316162 S )
#   Id( 1 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4841687679290771 S )
#   Id( 1 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4689748287200928 S )
#   Id( 1 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4718120098114014 S )
#   Id( 3 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4994263648986816 S )
#   Id( 3 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4815196990966797 S )
#   Id( 3 , 2 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.469078779220581 S )
#   Id( 3 , 4 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.484360694885254 S )
#   Id( 2 , 1 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.483483076095581 S )
#   Id( 2 , 3 , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.4954173564910889 S )
