# %% [markdown]
# ## Dyadic Events
#
# Compute behavioural traits for each individual for two mice (one for the tested strain and one control mouse), as well as computation of individual and social traits.

# %%
import sys
sys.path.insert(1, "../")

import sqlite3
from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
from lmtanalysis import BuildEventTrain3, BuildEventTrain4, BuildEventFollowZone, BuildEventRear5, BuildEventFloorSniffing,\
    BuildEventSocialApproach, BuildEventSocialEscape, BuildEventApproachContact,\
    BuildEventApproachRear, BuildEventGroup2, BuildEventGroup3, BuildEventGroup4,\
    BuildEventStop, BuildEventWaterPoint

from tkinter.filedialog import askopenfilename
from lmtanalysis.Util import getMinTMaxTAndFileNameInput





if __name__ == '__main__':
    
    print("Code launched.")
    '''
    compute behavioural traits for each individual for two mice (one for the tested strain and one control mouse)
    computation of individual and social traits.
    '''
 
        
    files = askopenfilename( title="Choose a set of file to process", multiple=1 )
    tmin, tmax, text_file = getMinTMaxTAndFileNameInput()

    '''
    min_dur = 10*oneSecond
    max_dur = min_dur + 10*oneMinute
    '''
    
    behaviouralEventOneMouse = ["Contact", "Group2", "Huddling", "Move isolated", "Move in contact", "Rearing", "Rear isolated", "Rear in contact", "Stop isolated", "WallJump"]
    behaviouralEventTwoMice = ["Approach contact", "Approach rear", "Break contact", "Contact", "FollowZone Isolated", "Group2", "Oral-oral Contact", "Oral-genital Contact", "Side by side Contact", "Side by side Contact, opposite way", "Social approach", "Social escape", "Train2"] 
    
    for file in files:
        
        print(file)
        connection = sqlite3.connect( file )
        
        pool = AnimalPool( )
        pool.loadAnimals( connection )
        
        pool.loadDetection( start = tmin, end = tmax )
        
        for animal in pool.animalDictionnary.keys():
            
            print ( pool.animalDictionnary[animal].RFID )
            #total distance traveled
            totalDistance = pool.animalDictionnary[animal].getDistance(tmin = tmin , tmax = tmax )
            resTotalDistance = [file, pool.animalDictionnary[animal].RFID, tmin, tmax, totalDistance]
            text_file.write( "{}\t{}\t{}\t{}\t{}\t{}\n".format( file, pool.animalDictionnary[animal].RFID, pool.animalDictionnary[animal].genotype, tmin, tmax, totalDistance ) ) 
  
            
        for behavEvent in behaviouralEventOneMouse:
            
            print( "computing individual event: {}".format(behavEvent))    
            behavEventTimeLine = {}
        
            for animal in pool.animalDictionnary.keys():
                behavEventTimeLine[animal] = EventTimeLine( connection, behavEvent, animal, minFrame=tmin, maxFrame=tmax )
                
                event = behavEventTimeLine[animal]
                
                totalEventDuration = event.getTotalLength()
                nbEvent = event.getNumberOfEvent(minFrame = tmin, maxFrame = tmax)

                
                print(event.eventName, event.idA, totalEventDuration, nbEvent)
                
                resOneMouse = [file, event.eventName, pool.animalDictionnary[animal].RFID, totalEventDuration, nbEvent]
                text_file.write( "{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\n".format( file, event.eventName, pool.animalDictionnary[animal].RFID, pool.animalDictionnary[animal].genotype, tmin, tmax, totalEventDuration, nbEvent ) ) 
                       
                

        for behavEvent in behaviouralEventTwoMice:
            
            print( "computing {} density".format(behavEvent))
            
            for animal in pool.animalDictionnary.keys():
                for idAnimalB in pool.animalDictionnary.keys():
                    if ( animal == idAnimalB ):
                        continue
                
                    behavEventTimeLine[animal, idAnimalB] = EventTimeLine( connection, behavEvent, animal, idAnimalB, minFrame=tmin, maxFrame=tmax )
                    
                    event = behavEventTimeLine[animal, idAnimalB]
                        
                    totalEventDuration = event.getTotalLength()
                    nbEvent = event.getNumberOfEvent(minFrame = tmin, maxFrame = tmax)
            
                        
                    print( behavEvent, pool.animalDictionnary[animal].RFID, pool.animalDictionnary[idAnimalB].RFID )
                
                    resSame = [file, behavEvent, pool.animalDictionnary[animal].RFID, pool.animalDictionnary[idAnimalB].RFID, tmin, tmax, totalEventDuration, nbEvent]
                
                    text_file.write( "{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\n".format( file, behavEvent, pool.animalDictionnary[animal].RFID, pool.animalDictionnary[animal].genotype, pool.animalDictionnary[idAnimalB].RFID, pool.animalDictionnary[idAnimalB].genotype, tmin, tmax, totalEventDuration, nbEvent ) ) 
            

    text_file.write( "\n" )
    text_file.close()
                
    print( "FINISHED" )
# Out:
# Code launched.
# Enter time information in frame. You can also set in days, hour, minutes
# valid entries: 100, 1d, 1.5d, 23.5h, 1d 2h 3m 4s 5f
# Starting t : 0
# Entry (in frame) : 0
# Ending t : 2d
# Entry (in frame) : 5184000
# Enter file name to save data (.txt will be added) : dyadic_experiment5
# D:/live mouse tracker data/Experiment 5/Experiment 5.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:2 Name:B RFID:000022986495 Genotype:KO User1:None
# Animal Id:4 Name:D RFID:000022986494 Genotype:KO User1:None
# Animal Id:1 Name:A RFID:000022986396 Genotype:WT User1:None
# Animal Id:3 Name:C RFID:000022986530 Genotype:WT User1:None
# Animal Id:2 Name:B RFID:000022986495 Genotype:KO User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5184000
# Animal Id:2 Name:B RFID:000022986495 Genotype:KO User1:None   2948827  detections loaded in 222.10061311721802 seconds.
# Animal Id:4 Name:D RFID:000022986494 Genotype:KO User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5184000
# Animal Id:4 Name:D RFID:000022986494 Genotype:KO User1:None   2820049  detections loaded in 1023.5402595996857 seconds.
# Animal Id:1 Name:A RFID:000022986396 Genotype:WT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5184000
# Animal Id:1 Name:A RFID:000022986396 Genotype:WT User1:None   2964017  detections loaded in 1279.9381511211395 seconds.
# Animal Id:3 Name:C RFID:000022986530 Genotype:WT User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y, MASS_Z, FRONT_X, FRONT_Y, FRONT_Z, BACK_X, BACK_Y, BACK_Z,REARING,LOOK_UP,LOOK_DOWN FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=0 AND FRAMENUMBER<=5184000
# Animal Id:3 Name:C RFID:000022986530 Genotype:WT User1:None   2754283  detections loaded in 894.2271184921265 seconds.
# 000022986495
# Compute total distance min:0 max:5184000
# 000022986494
# Compute total distance min:0 max:5184000
# 000022986396
# Compute total distance min:0 max:5184000
# 000022986530
# Compute total distance min:0 max:5184000
# computing individual event: Contact
# Contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12846  records loaded in  1755.5475358963013 S )
# Contact 2 750720 12846
# Contact  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 10831  records loaded in  878.7354636192322 S )
# Contact 4 689725 10831
# Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12567  records loaded in  10.452025413513184 S )
# Contact 1 817982 12567
# Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12282  records loaded in  10.808451175689697 S )
# Contact 3 786671 12282
# computing individual event: Group2
# Group2  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13336  records loaded in  9.855238437652588 S )
# Group2 2 403916 13336
# Group2  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 11626  records loaded in  9.685187816619873 S )
# Group2 4 355729 11626
# Group2  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13707  records loaded in  9.655195713043213 S )
# Group2 1 449620 13707
# Group2  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13327  records loaded in  9.476645708084106 S )
# Group2 3 420041 13327
# computing individual event: Huddling
# Huddling  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 0  records loaded in  9.256103992462158 S )
# Huddling 2 0 0
# Huddling  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 0  records loaded in  9.420152425765991 S )
# Huddling 4 0 0
# Huddling  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 0  records loaded in  9.36767053604126 S )
# Huddling 1 0 0
# Huddling  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 0  records loaded in  9.274104118347168 S )
# Huddling 3 0 0
# computing individual event: Move isolated
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 84584  records loaded in  9.889233112335205 S )
# Move isolated 2 256268 84584
# Move isolated  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 78055  records loaded in  10.155293226242065 S )
# Move isolated 4 262212 78055
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 99759  records loaded in  10.318331003189087 S )
# Move isolated 1 269373 99759
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 74805  records loaded in  10.647405862808228 S )
# Move isolated 3 221547 74805
# computing individual event: Move in contact
# Move in contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 23373  records loaded in  9.499157190322876 S )
# Move in contact 2 98226 23373
# Move in contact  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 22609  records loaded in  9.54667592048645 S )
# Move in contact 4 95846 22609
# Move in contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 24748  records loaded in  9.501652956008911 S )
# Move in contact 1 107194 24748
# Move in contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 24935  records loaded in  9.576163053512573 S )
# Move in contact 3 105308 24935
# computing individual event: Rearing
# Rearing  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 47306  records loaded in  10.386356830596924 S )
# Rearing 2 2085265 47306
# Rearing  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 60337  records loaded in  10.564387321472168 S )
# Rearing 4 1998333 60337
# Rearing  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 40053  records loaded in  10.400854349136353 S )
# Rearing 1 2021612 40053
# Rearing  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 47332  records loaded in  10.586445331573486 S )
# Rearing 3 1987080 47332
# computing individual event: Rear isolated
# Rear isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 35094  records loaded in  9.480598449707031 S )
# Rear isolated 2 53494 35094
# Rear isolated  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 48315  records loaded in  9.481141567230225 S )
# Rear isolated 4 82176 48315
# Rear isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 23966  records loaded in  9.401123285293579 S )
# Rear isolated 1 44355 23966
# Rear isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 32756  records loaded in  9.556157350540161 S )
# Rear isolated 3 49153 32756
# computing individual event: Rear in contact
# Rear in contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5092  records loaded in  9.4378342628479 S )
# Rear in contact 2 12086 5092
# Rear in contact  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 4706  records loaded in  9.304607152938843 S )
# Rear in contact 4 11445 4706
# Rear in contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 6366  records loaded in  9.369656085968018 S )
# Rear in contact 1 14404 6366
# Rear in contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5301  records loaded in  9.207092523574829 S )
# Rear in contact 3 12494 5301
# computing individual event: Stop isolated
# Stop isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 61695  records loaded in  10.649404525756836 S )
# Stop isolated 2 1942016 61695
# Stop isolated  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 55595  records loaded in  10.272217273712158 S )
# Stop isolated 4 1868286 55595
# Stop isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 57162  records loaded in  10.324331521987915 S )
# Stop isolated 1 1877244 57162
# Stop isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 51684  records loaded in  10.272364854812622 S )
# Stop isolated 3 1746286 51684
# computing individual event: WallJump
# WallJump  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 1713  records loaded in  9.164593696594238 S )
# WallJump 2 3816 1713
# WallJump  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 1922  records loaded in  9.233110666275024 S )
# WallJump 4 4381 1922
# WallJump  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 1719  records loaded in  9.274099111557007 S )
# WallJump 1 3837 1719
# WallJump  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 1667  records loaded in  9.266104936599731 S )
# WallJump 3 3756 1667
# computing Approach contact density
# Approach contact  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 37246  records loaded in  9.713193893432617 S )
# Approach contact 000022986495 000022986494
# Approach contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 45707  records loaded in  9.60919189453125 S )
# Approach contact 000022986495 000022986396
# Approach contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 43475  records loaded in  9.625957489013672 S )
# Approach contact 000022986495 000022986530
# Approach contact  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 36241  records loaded in  9.509742736816406 S )
# Approach contact 000022986494 000022986495
# Approach contact  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 42485  records loaded in  9.629698276519775 S )
# Approach contact 000022986494 000022986396
# Approach contact  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 37367  records loaded in  9.542175054550171 S )
# Approach contact 000022986494 000022986530
# Approach contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 45150  records loaded in  9.47364592552185 S )
# Approach contact 000022986396 000022986495
# Approach contact  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 43115  records loaded in  9.588168859481812 S )
# Approach contact 000022986396 000022986494
# Approach contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 46393  records loaded in  9.503146409988403 S )
# Approach contact 000022986396 000022986530
# Approach contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 42246  records loaded in  9.720196008682251 S )
# Approach contact 000022986530 000022986495
# Approach contact  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 38403  records loaded in  9.576164960861206 S )
# Approach contact 000022986530 000022986494
# Approach contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 48472  records loaded in  9.637681484222412 S )
# Approach contact 000022986530 000022986396
# computing Approach rear density
# Approach rear  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2469  records loaded in  9.3201162815094 S )
# Approach rear 000022986495 000022986494
# Approach rear  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 3307  records loaded in  9.046042680740356 S )
# Approach rear 000022986495 000022986396
# Approach rear  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2661  records loaded in  9.358113050460815 S )
# Approach rear 000022986495 000022986530
# Approach rear  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2615  records loaded in  9.157092332839966 S )
# Approach rear 000022986494 000022986495
# Approach rear  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 3098  records loaded in  9.248595952987671 S )
# Approach rear 000022986494 000022986396
# Approach rear  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2812  records loaded in  9.0470552444458 S )
# Approach rear 000022986494 000022986530
# Approach rear  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 3238  records loaded in  9.238624811172485 S )
# Approach rear 000022986396 000022986495
# Approach rear  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2951  records loaded in  9.20707893371582 S )
# Approach rear 000022986396 000022986494
# Approach rear  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 3906  records loaded in  9.164577007293701 S )
# Approach rear 000022986396 000022986530
# Approach rear  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2824  records loaded in  9.280115127563477 S )
# Approach rear 000022986530 000022986495
# Approach rear  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2850  records loaded in  9.151585340499878 S )
# Approach rear 000022986530 000022986494
# Approach rear  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 4199  records loaded in  9.267108678817749 S )
# Approach rear 000022986530 000022986396
# computing Break contact density
# Break contact  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2430  records loaded in  9.24708890914917 S )
# Break contact 000022986495 000022986494
# Break contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2725  records loaded in  9.262092113494873 S )
# Break contact 000022986495 000022986396
# Break contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2801  records loaded in  9.202078819274902 S )
# Break contact 000022986495 000022986530
# Break contact  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2581  records loaded in  9.25809121131897 S )
# Break contact 000022986494 000022986495
# Break contact  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2420  records loaded in  9.509596586227417 S )
# Break contact 000022986494 000022986396
# Break contact  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2423  records loaded in  9.212589502334595 S )
# Break contact 000022986494 000022986530
# Break contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2715  records loaded in  9.266602754592896 S )
# Break contact 000022986396 000022986495
# Break contact  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2528  records loaded in  9.16557765007019 S )
# Break contact 000022986396 000022986494
# Break contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2798  records loaded in  9.244100332260132 S )
# Break contact 000022986396 000022986530
# Break contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2629  records loaded in  9.110089302062988 S )
# Break contact 000022986530 000022986495
# Break contact  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 2244  records loaded in  9.336044549942017 S )
# Break contact 000022986530 000022986494
# Break contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 3015  records loaded in  9.2940993309021 S )
# Break contact 000022986530 000022986396
# computing Contact density
# Contact  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 11032  records loaded in  9.502174377441406 S )
# Contact 000022986495 000022986494
# Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 11454  records loaded in  9.45564079284668 S )
# Contact 000022986495 000022986396
# Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 11653  records loaded in  9.464644432067871 S )
# Contact 000022986495 000022986530
# Contact  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 11032  records loaded in  9.523164987564087 S )
# Contact 000022986494 000022986495
# Contact  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 10692  records loaded in  9.311127185821533 S )
# Contact 000022986494 000022986396
# Contact  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 10146  records loaded in  9.416142225265503 S )
# Contact 000022986494 000022986530
# Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 11453  records loaded in  9.490264892578125 S )
# Contact 000022986396 000022986495
# Contact  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 10689  records loaded in  9.409125328063965 S )
# Contact 000022986396 000022986494
# Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12150  records loaded in  9.550828218460083 S )
# Contact 000022986396 000022986530
# Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 11653  records loaded in  9.672220468521118 S )
# Contact 000022986530 000022986495
# Contact  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 10145  records loaded in  9.617172002792358 S )
# Contact 000022986530 000022986494
# Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12151  records loaded in  9.483169794082642 S )
# Contact 000022986530 000022986396
# computing FollowZone Isolated density
# FollowZone Isolated  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5953  records loaded in  9.286603212356567 S )
# FollowZone Isolated 000022986495 000022986494
# FollowZone Isolated  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5365  records loaded in  9.370115756988525 S )
# FollowZone Isolated 000022986495 000022986396
# FollowZone Isolated  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5866  records loaded in  9.70823049545288 S )
# FollowZone Isolated 000022986495 000022986530
# FollowZone Isolated  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 6238  records loaded in  9.56015920639038 S )
# FollowZone Isolated 000022986494 000022986495
# FollowZone Isolated  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5316  records loaded in  9.404627799987793 S )
# FollowZone Isolated 000022986494 000022986396
# FollowZone Isolated  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5556  records loaded in  9.380119800567627 S )
# FollowZone Isolated 000022986494 000022986530
# FollowZone Isolated  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5727  records loaded in  9.304129123687744 S )
# FollowZone Isolated 000022986396 000022986495
# FollowZone Isolated  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5154  records loaded in  9.330107927322388 S )
# FollowZone Isolated 000022986396 000022986494
# FollowZone Isolated  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 6165  records loaded in  9.282108306884766 S )
# FollowZone Isolated 000022986396 000022986530
# FollowZone Isolated  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5870  records loaded in  9.465152025222778 S )
# FollowZone Isolated 000022986530 000022986495
# FollowZone Isolated  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5782  records loaded in  9.312103748321533 S )
# FollowZone Isolated 000022986530 000022986494
# FollowZone Isolated  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 6093  records loaded in  9.497145175933838 S )
# FollowZone Isolated 000022986530 000022986396
# computing Group2 density
# Group2  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 4333  records loaded in  9.469315528869629 S )
# Group2 000022986495 000022986494
# Group2  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 4849  records loaded in  9.524150609970093 S )
# Group2 000022986495 000022986396
# Group2  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 4771  records loaded in  9.483142137527466 S )
# Group2 000022986495 000022986530
# Group2  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 4333  records loaded in  9.383663415908813 S )
# Group2 000022986494 000022986495
# Group2  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 4133  records loaded in  9.448665380477905 S )
# Group2 000022986494 000022986396
# Group2  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 3743  records loaded in  9.285096883773804 S )
# Group2 000022986494 000022986530
# Group2  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 4848  records loaded in  9.492157936096191 S )
# Group2 000022986396 000022986495
# Group2  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 4133  records loaded in  9.412125825881958 S )
# Group2 000022986396 000022986494
# Group2  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5398  records loaded in  9.419174194335938 S )
# Group2 000022986396 000022986530
# Group2  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 4771  records loaded in  9.800721645355225 S )
# Group2 000022986530 000022986495
# Group2  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 3742  records loaded in  9.991256713867188 S )
# Group2 000022986530 000022986494
# Group2  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 5399  records loaded in  9.77520751953125 S )
# Group2 000022986530 000022986396
# computing Oral-oral Contact density
# Oral-oral Contact  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 9716  records loaded in  9.67018747329712 S )
# Oral-oral Contact 000022986495 000022986494
# Oral-oral Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12073  records loaded in  9.479140520095825 S )
# Oral-oral Contact 000022986495 000022986396
# Oral-oral Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12350  records loaded in  9.470288038253784 S )
# Oral-oral Contact 000022986495 000022986530
# Oral-oral Contact  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 9716  records loaded in  9.382130146026611 S )
# Oral-oral Contact 000022986494 000022986495
# Oral-oral Contact  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 11752  records loaded in  9.675185680389404 S )
# Oral-oral Contact 000022986494 000022986396
# Oral-oral Contact  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 11024  records loaded in  9.550156116485596 S )
# Oral-oral Contact 000022986494 000022986530
# Oral-oral Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12073  records loaded in  9.555663108825684 S )
# Oral-oral Contact 000022986396 000022986495
# Oral-oral Contact  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 11752  records loaded in  9.297114133834839 S )
# Oral-oral Contact 000022986396 000022986494
# Oral-oral Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 14361  records loaded in  9.611186027526855 S )
# Oral-oral Contact 000022986396 000022986530
# Oral-oral Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12350  records loaded in  9.42314624786377 S )
# Oral-oral Contact 000022986530 000022986495
# Oral-oral Contact  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 11024  records loaded in  9.625173807144165 S )
# Oral-oral Contact 000022986530 000022986494
# Oral-oral Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 14361  records loaded in  9.626660585403442 S )
# Oral-oral Contact 000022986530 000022986396
# computing Oral-genital Contact density
# Oral-genital Contact  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 10922  records loaded in  9.345110893249512 S )
# Oral-genital Contact 000022986495 000022986494
# Oral-genital Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13594  records loaded in  9.542156457901001 S )
# Oral-genital Contact 000022986495 000022986396
# Oral-genital Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 14965  records loaded in  9.43713116645813 S )
# Oral-genital Contact 000022986495 000022986530
# Oral-genital Contact  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 10419  records loaded in  9.350166320800781 S )
# Oral-genital Contact 000022986494 000022986495
# Oral-genital Contact  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12505  records loaded in  9.36463475227356 S )
# Oral-genital Contact 000022986494 000022986396
# Oral-genital Contact  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12363  records loaded in  9.496736288070679 S )
# Oral-genital Contact 000022986494 000022986530
# Oral-genital Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13848  records loaded in  9.426663398742676 S )
# Oral-genital Contact 000022986396 000022986495
# Oral-genital Contact  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13081  records loaded in  9.429129362106323 S )
# Oral-genital Contact 000022986396 000022986494
# Oral-genital Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 15621  records loaded in  9.540154933929443 S )
# Oral-genital Contact 000022986396 000022986530
# Oral-genital Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 14547  records loaded in  9.730707168579102 S )
# Oral-genital Contact 000022986530 000022986495
# Oral-genital Contact  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13573  records loaded in  9.926092147827148 S )
# Oral-genital Contact 000022986530 000022986494
# Oral-genital Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 14847  records loaded in  9.485142230987549 S )
# Oral-genital Contact 000022986530 000022986396
# computing Side by side Contact density
# Side by side Contact  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12092  records loaded in  9.341615200042725 S )
# Side by side Contact 000022986495 000022986494
# Side by side Contact  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13888  records loaded in  9.575182914733887 S )
# Side by side Contact 000022986495 000022986396
# Side by side Contact  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 15341  records loaded in  9.312103033065796 S )
# Side by side Contact 000022986495 000022986530
# Side by side Contact  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12092  records loaded in  9.498175859451294 S )
# Side by side Contact 000022986494 000022986495
# Side by side Contact  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13657  records loaded in  9.519150018692017 S )
# Side by side Contact 000022986494 000022986396
# Side by side Contact  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13281  records loaded in  9.42612886428833 S )
# Side by side Contact 000022986494 000022986530
# Side by side Contact  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13888  records loaded in  9.418126344680786 S )
# Side by side Contact 000022986396 000022986495
# Side by side Contact  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13657  records loaded in  9.348631143569946 S )
# Side by side Contact 000022986396 000022986494
# Side by side Contact  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 16350  records loaded in  9.8892343044281 S )
# Side by side Contact 000022986396 000022986530
# Side by side Contact  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 15341  records loaded in  9.568161010742188 S )
# Side by side Contact 000022986530 000022986495
# Side by side Contact  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13281  records loaded in  9.664196729660034 S )
# Side by side Contact 000022986530 000022986494
# Side by side Contact  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 16350  records loaded in  9.59016752243042 S )
# Side by side Contact 000022986530 000022986396
# computing Side by side Contact, opposite way density
# Side by side Contact, opposite way  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12304  records loaded in  9.74020004272461 S )
# Side by side Contact, opposite way 000022986495 000022986494
# Side by side Contact, opposite way  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13386  records loaded in  9.96925163269043 S )
# Side by side Contact, opposite way 000022986495 000022986396
# Side by side Contact, opposite way  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 15546  records loaded in  9.626240253448486 S )
# Side by side Contact, opposite way 000022986495 000022986530
# Side by side Contact, opposite way  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 12304  records loaded in  9.560275793075562 S )
# Side by side Contact, opposite way 000022986494 000022986495
# Side by side Contact, opposite way  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13747  records loaded in  9.575515508651733 S )
# Side by side Contact, opposite way 000022986494 000022986396
# Side by side Contact, opposite way  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13312  records loaded in  9.38778305053711 S )
# Side by side Contact, opposite way 000022986494 000022986530
# Side by side Contact, opposite way  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13386  records loaded in  9.492651462554932 S )
# Side by side Contact, opposite way 000022986396 000022986495
# Side by side Contact, opposite way  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13747  records loaded in  9.579264163970947 S )
# Side by side Contact, opposite way 000022986396 000022986494
# Side by side Contact, opposite way  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 15835  records loaded in  9.590672016143799 S )
# Side by side Contact, opposite way 000022986396 000022986530
# Side by side Contact, opposite way  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 15546  records loaded in  9.480854988098145 S )
# Side by side Contact, opposite way 000022986530 000022986495
# Side by side Contact, opposite way  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 13312  records loaded in  9.524178504943848 S )
# Side by side Contact, opposite way 000022986530 000022986494
# Side by side Contact, opposite way  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 15835  records loaded in  9.494207620620728 S )
# Side by side Contact, opposite way 000022986530 000022986396
# computing Social approach density
# Social approach  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 58009  records loaded in  9.8642418384552 S )
# Social approach 000022986495 000022986494
# Social approach  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 62756  records loaded in  9.551156520843506 S )
# Social approach 000022986495 000022986396
# Social approach  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 64034  records loaded in  9.743200063705444 S )
# Social approach 000022986495 000022986530
# Social approach  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 57154  records loaded in  9.599671125411987 S )
# Social approach 000022986494 000022986495
# Social approach  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 57852  records loaded in  9.408160924911499 S )
# Social approach 000022986494 000022986396
# Social approach  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 53981  records loaded in  9.459740161895752 S )
# Social approach 000022986494 000022986530
# Social approach  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 62383  records loaded in  9.545674800872803 S )
# Social approach 000022986396 000022986495
# Social approach  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 56313  records loaded in  9.651180267333984 S )
# Social approach 000022986396 000022986494
# Social approach  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 59200  records loaded in  9.603182554244995 S )
# Social approach 000022986396 000022986530
# Social approach  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 60149  records loaded in  10.194302082061768 S )
# Social approach 000022986530 000022986495
# Social approach  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 54107  records loaded in  9.861233711242676 S )
# Social approach 000022986530 000022986494
# Social approach  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 61910  records loaded in  9.605180501937866 S )
# Social approach 000022986530 000022986396
# computing Social escape density
# Social escape  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 22951  records loaded in  9.4486403465271 S )
# Social escape 000022986495 000022986494
# Social escape  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 27108  records loaded in  9.22508978843689 S )
# Social escape 000022986495 000022986396
# Social escape  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 27489  records loaded in  9.433130979537964 S )
# Social escape 000022986495 000022986530
# Social escape  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 23483  records loaded in  9.276112794876099 S )
# Social escape 000022986494 000022986495
# Social escape  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 24701  records loaded in  9.253090143203735 S )
# Social escape 000022986494 000022986396
# Social escape  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 24604  records loaded in  9.219082593917847 S )
# Social escape 000022986494 000022986530
# Social escape  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 25382  records loaded in  9.323105812072754 S )
# Social escape 000022986396 000022986495
# Social escape  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 24358  records loaded in  9.336132526397705 S )
# Social escape 000022986396 000022986494
# Social escape  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 27868  records loaded in  9.316117286682129 S )
# Social escape 000022986396 000022986530
# Social escape  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 26037  records loaded in  9.268637895584106 S )
# Social escape 000022986530 000022986495
# Social escape  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 24595  records loaded in  9.297658205032349 S )
# Social escape 000022986530 000022986494
# Social escape  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 28861  records loaded in  9.454163789749146 S )
# Social escape 000022986530 000022986396
# computing Train2 density
# Train2  Id( 2 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 23  records loaded in  9.17757773399353 S )
# Train2 000022986495 000022986494
# Train2  Id( 2 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 31  records loaded in  9.015366077423096 S )
# Train2 000022986495 000022986396
# Train2  Id( 2 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 29  records loaded in  9.201597452163696 S )
# Train2 000022986495 000022986530
# Train2  Id( 4 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 15  records loaded in  9.252609014511108 S )
# Train2 000022986494 000022986495
# Train2  Id( 4 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 34  records loaded in  9.19758129119873 S )
# Train2 000022986494 000022986396
# Train2  Id( 4 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 17  records loaded in  9.153600692749023 S )
# Train2 000022986494 000022986530
# Train2  Id( 1 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 41  records loaded in  9.13807725906372 S )
# Train2 000022986396 000022986495
# Train2  Id( 1 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 31  records loaded in  9.08207893371582 S )
# Train2 000022986396 000022986494
# Train2  Id( 1 , 3 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 43  records loaded in  9.398637294769287 S )
# Train2 000022986396 000022986530
# Train2  Id( 3 , 2 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 16  records loaded in  9.118103265762329 S )
# Train2 000022986530 000022986495
# Train2  Id( 3 , 4 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 28  records loaded in  9.215081453323364 S )
# Train2 000022986530 000022986494
# Train2  Id( 3 , 1 , None , None ) Min/maxFrame: ( 0 / 5184000 ) Loaded ( 25  records loaded in  9.344122648239136 S )
# Train2 000022986530 000022986396
# FINISHED
