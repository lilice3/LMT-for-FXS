# %% [markdown]
# ## All Profiles Relatives
#
# Returns a file with list of events related to another animal contact.

# %%
import sys
sys.path.insert(1, "../")

import sqlite3
from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.FileUtil import getFilesToProcess
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
from lmtanalysis import BuildEventTrain3, BuildEventTrain4, BuildEventTrain2, BuildEventFollowZone, BuildEventRear5, BuildEventFloorSniffing,\
    BuildEventSocialApproach, BuildEventSocialEscape, BuildEventApproachContact,BuildEventOralOralContact,\
    BuildEventApproachRear, BuildEventGroup2, BuildEventGroup3, BuildEventGroup4, BuildEventOralGenitalContact, \
    BuildEventStop, BuildEventWaterPoint,  \
    BuildEventMove, BuildEventGroup3MakeBreak, BuildEventGroup4MakeBreak
    
import matplotlib.gridspec as gridspec
from tkinter.filedialog import askopenfilename


'''
setName = "night 1"
minDur = 0*oneDay
maxDur = minDur+ 23*oneHour
'''

'''
setName = "night 2"
minDur = 1*oneDay
maxDur = minDur+ 23*oneHour
'''


setName = "night 1"
minDur = 0*oneDay
maxDur = minDur+ 23*oneHour

def getValue( connection, animal, animalListWT, eventName , type="duration" ):
    
    timeLineWT1 = EventTimeLine( connection, eventName, animalListWT[0].baseId, minFrame=minDur, maxFrame=maxDur )
    timeLineWT2 = EventTimeLine( connection, eventName, animalListWT[1].baseId, minFrame=minDur, maxFrame=maxDur )
    timeLineKO = EventTimeLine( connection, eventName, animal.baseId, minFrame=minDur, maxFrame=maxDur )

    scoreWT1 = 0
    scoreWT2 = 0
    scoreKO = 0 
    
    if ( type == "duration" ):
         
        scoreWT1 = timeLineWT1.getTotalLength()
        scoreWT2 = timeLineWT2.getTotalLength()
        scoreKO = timeLineKO.getTotalLength() 
    
    if ( type == "number" ):
        
        scoreWT1 = len( timeLineWT1.eventList )
        scoreWT2 = len( timeLineWT2.eventList )
        scoreKO = len ( timeLineKO.eventList ) 
     
    meanScoreWT = ( ( scoreWT1+scoreWT2 ) / 2 )
    
    value = 0
    if ( not meanScoreWT == 0 ):
        value = scoreKO / meanScoreWT
        value = value-1
    
    return value    

def drawGraph( file, connection, animal, animalListWT , drawContext ):

    print( "*********** DRAWGRAPH")

    event_list = []
    values = []
    colors = []
    
    event_list.append( "Moving alone" )
    colors.append( "black" )
    values.append( getValue( connection, animal, animalListWT, "Move isolated" ) )
    
    event_list.append( "Stopped alone" )
    colors.append( "black" )
    values.append( getValue( connection, animal, animalListWT, "Stop isolated" ) )

    event_list.append( "Rearing isolated" )
    colors.append( "black" )
    values.append( getValue( connection, animal, animalListWT, "Rear isolated" ) )

    event_list.append( "Heading down" )
    colors.append( "black" )
    values.append( getValue( connection, animal, animalListWT, "Look down" ) )
    
    event_list.append( "Huddled" )
    colors.append( "black" )
    values.append( getValue( connection, animal, animalListWT, "Huddling" ) )

    event_list.append( "Jumping" )
    colors.append( "black" )
    values.append( getValue( connection, animal, animalListWT, "WallJump" ) )

    event_list.append( "SAP" )
    colors.append( "black" )
    values.append( getValue( connection, animal, animalListWT, "SAP" ) )

    ''' separator '''
    
    event_list.append( "Moving in contact" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Move in contact" ) )
        
    event_list.append( "Rearing in contact" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Rear in contact" ) )
    
    event_list.append( "Side by side sw" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Side by side Contact" ) )
    
    event_list.append( "Side by side ow" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Side by side Contact, opposite way" ) )
    
    event_list.append( "Nose-nose" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Oral-oral Contact" ) )
    
    event_list.append( "Nose-anogenital" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Oral-genital Contact" ) )
    
    ''' separator '''
    
    event_list.append( "Group of 2 mice" )
    colors.append( "orange" )
    values.append( getValue( connection, animal, animalListWT, "Group2" ) )

    event_list.append( "Group of 3 mice" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Group3" ) )

    event_list.append( "Out of nest" )
    colors.append( "black" )
    values.append( getValue( connection, animal, animalListWT, "Nest3" ) )

    event_list.append( "Train of 2 mice" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Train2" ) )

    event_list.append( "Train of 3 mice" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Train3" ) )

    event_list.append( "Train of 4 mice" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Train4" ) )

    ''' separator '''    
        
    event_list.append( "Approach in social range (number)" )
    colors.append( "green" )
    values.append( getValue( connection, animal, animalListWT, "Social approach" , type="number" ) )
    
    event_list.append( "Approach a mouse in rearing in social range (number)" )
    colors.append( "green" )
    values.append( getValue( connection, animal, animalListWT, "Approach rear" , type = "number" ) )
    
    event_list.append( "Making contact (duration)" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Approach contact" ) )

    event_list.append( "Making contact (number)" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Approach contact" , type="number" ) )

    event_list.append( "Contact" )
    colors.append( "red" )
    values.append( getValue( connection, animal, animalListWT, "Contact" ) )
    
    event_list.append( "Moving away from a mouse in social range (number)" )
    colors.append( "green" )
    values.append( getValue( connection, animal, animalListWT, "Social escape", type= "number" ) )
    
    event_list.append( "Breaking contact (number)" )
    colors.append( "green" )
    values.append( getValue( connection, animal, animalListWT, "Social escape" , type="number" ) )
    
    event_list.append( "Follow within path" )
    colors.append( "green" )
    values.append( getValue( connection, animal, animalListWT, "FollowZone Isolated" ) )
    
    ''' separator '''
    
    event_list.append( "Group making of 3 mice (number)" )
    colors.append( "purple" )
    values.append( getValue( connection, animal, animalListWT, "Group 3 make" , type="number") )

    event_list.append( "Group making of 4 mice (number)" )
    colors.append( "purple" )
    values.append( getValue( connection, animal, animalListWT, "Group 4 make" , type="number") )

    event_list.append( "Group breaking of 3 mice (number)" )
    colors.append( "pink" )
    values.append( getValue( connection, animal, animalListWT, "Group 3 break" , type="number") )

    event_list.append( "Group breaking of 4 mice (number)" )
    colors.append( "pink" )
    values.append( getValue( connection, animal, animalListWT, "Group 4 break" , type="number") )
        
    event_list.append( "seq oral oral - oral geni (number)" )
    colors.append( "pink" )
    values.append( getValue( connection, animal, animalListWT, "seq oral oral - oral genital", type="number" ) )
        
    event_list.append( "seq oral geni - oral oral (number)" )
    colors.append( "pink" )
    values.append( getValue( connection, animal, animalListWT, "seq oral geni - oral oral" , type="number" ) )
        
    
    
    #h = plt.bar( range( len(event_list) ) , values, label=event_list , color=colors )
    
    #xticks_pos = [0.65*patch.get_width() + patch.get_xy()[0] for patch in h]
    
    title= animal.RFID + " -ID- " + animal.genotype
    
    text_file = open ( file+title+setName+".txt", "w")

    text_file.write ( "*******\n" )
    
    text_file.write ( file + "\n")
    
    text_file.write ( title + "\n" )    
    for i in range ( 0, len(event_list ) ):
        text_file.write( event_list[i] + "\t" +  str( values[i] ) + "\n" )
    
                    
    text_file.write( "\n" )
    text_file.close()
    
    
    #plt.xticks( xticks_pos, event_list,  ha='right', rotation=45, fontsize="x-small" )
    #plt.title( title )
    #plt.show()
    
def graphIdentity( file ):
    
    '''
    draw 4 figures with all parameters    
    '''
    
    print(file)
    connection = sqlite3.connect( file )

    pool = AnimalPool( )
    pool.loadAnimals( connection )

    ''' create a list with WT and then KO '''
    
    animalListWT = pool.getAnimalsWithGenotype("WT")
    animalListKO = pool.getAnimalsWithGenotype("KO")

    ''' prepare figure '''
    
    for i in range( 2 ):
        drawGraph( file, connection, animalListKO[i] , animalListWT , None )
    
    

    #plt.savefig('test.pdf', bbox_inches='tight')

    

def getNumberOfEventWithList( connection, eventName, animalA , animalToCompareList ):
    
    sumOfEvent = 0
    for animalCandidate in animalToCompareList:
        
        timeLine = EventTimeLine( connection , eventName , animalA , animalCandidate )
        sumOfEvent += timeLine.getNbEvent()
    
    return sumOfEvent


if __name__ == '__main__':
    
    print("Code launched.")
    
    files = getFilesToProcess()
    
    for file in files:
        graphIdentity( file )
    
    #quit()
# Out:
# Code launched.
# D:/live mouse tracker data/data/Experiment 5/Experiment 5.sqlite
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:2 Name:B RFID:000022986495 Genotype:KO User1:None
# Animal Id:4 Name:D RFID:000022986494 Genotype:KO User1:None
# Animal Id:1 Name:A RFID:000022986396 Genotype:WT User1:None
# Animal Id:3 Name:C RFID:000022986530 Genotype:WT User1:None
# *********** DRAWGRAPH
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 43547  records loaded in  3.462782382965088 S )
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 39373  records loaded in  3.408770799636841 S )
# Move isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 42422  records loaded in  3.479785919189453 S )
# Stop isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 30837  records loaded in  3.609816312789917 S )
# Stop isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 26827  records loaded in  3.635822296142578 S )
# Stop isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 25220  records loaded in  3.637822151184082 S )
# Rear isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 16157  records loaded in  3.2797491550445557 S )
# Rear isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 28668  records loaded in  3.3227508068084717 S )
# Rear isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 24247  records loaded in  3.3097400665283203 S )
# Look down  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 3316  records loaded in  3.2587358951568604 S )
# Look down  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2429  records loaded in  3.3187499046325684 S )
# Look down  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 3330  records loaded in  3.2817423343658447 S )
# Huddling  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.253734827041626 S )
# Huddling  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.348756790161133 S )
# Huddling  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.281741142272949 S )
# WallJump  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 739  records loaded in  3.2297301292419434 S )
# WallJump  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 736  records loaded in  3.1937215328216553 S )
# WallJump  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 729  records loaded in  3.2057244777679443 S )
# SAP  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4417  records loaded in  3.2227280139923096 S )
# SAP  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4776  records loaded in  3.214726448059082 S )
# SAP  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4928  records loaded in  3.2737395763397217 S )
# Move in contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10728  records loaded in  3.2957444190979004 S )
# Move in contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10723  records loaded in  3.3562676906585693 S )
# Move in contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10096  records loaded in  3.339754819869995 S )
# Rear in contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 3602  records loaded in  3.3077473640441895 S )
# Rear in contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2816  records loaded in  3.277740478515625 S )
# Rear in contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2901  records loaded in  3.299745559692383 S )
# Side by side Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10873  records loaded in  3.4037692546844482 S )
# Side by side Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10820  records loaded in  3.450779914855957 S )
# Side by side Contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 9586  records loaded in  3.288742780685425 S )
# Side by side Contact, opposite way  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10079  records loaded in  3.2717394828796387 S )
# Side by side Contact, opposite way  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10897  records loaded in  3.3717617988586426 S )
# Side by side Contact, opposite way  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 9373  records loaded in  3.289743185043335 S )
# Oral-oral Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 11052  records loaded in  3.3171489238739014 S )
# Oral-oral Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 11344  records loaded in  3.2877395153045654 S )
# Oral-oral Contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 9670  records loaded in  3.3117480278015137 S )
# Oral-genital Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 11398  records loaded in  3.290743112564087 S )
# Oral-genital Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 12624  records loaded in  3.3077471256256104 S )
# Oral-genital Contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10657  records loaded in  3.319758892059326 S )
# Group2  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5348  records loaded in  3.288742780685425 S )
# Group2  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5503  records loaded in  3.30574631690979 S )
# Group2  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5560  records loaded in  3.2827420234680176 S )
# Group3  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2555  records loaded in  3.2627367973327637 S )
# Group3  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2465  records loaded in  3.2497341632843018 S )
# Group3  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2469  records loaded in  3.3837642669677734 S )
# Nest3  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.2077243328094482 S )
# Nest3  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.1997230052948 S )
# Nest3  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.2197272777557373 S )
# Train2  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 71  records loaded in  3.4007771015167236 S )
# Train2  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 41  records loaded in  3.2157180309295654 S )
# Train2  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 36  records loaded in  3.192721128463745 S )
# Train3  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 1  records loaded in  3.2847423553466797 S )
# Train3  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 1  records loaded in  3.1947295665740967 S )
# Train3  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 1  records loaded in  3.182710886001587 S )
# Train4  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.1887285709381104 S )
# Train4  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.2077159881591797 S )
# Train4  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.263737440109253 S )
# Social approach  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 43941  records loaded in  3.478794813156128 S )
# Social approach  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 42578  records loaded in  3.5309126377105713 S )
# Social approach  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 42846  records loaded in  3.48978853225708 S )
# Approach rear  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5218  records loaded in  3.2547357082366943 S )
# Approach rear  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4873  records loaded in  3.246732711791992 S )
# Approach rear  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4109  records loaded in  3.266737461090088 S )
# Approach contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 32082  records loaded in  3.415771722793579 S )
# Approach contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 28862  records loaded in  3.392766237258911 S )
# Approach contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 29247  records loaded in  3.425773859024048 S )
# Approach contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 32082  records loaded in  3.403769016265869 S )
# Approach contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 28862  records loaded in  3.4477789402008057 S )
# Approach contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 29247  records loaded in  3.4107706546783447 S )
# Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5076  records loaded in  3.3607592582702637 S )
# Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5226  records loaded in  3.4327759742736816 S )
# Contact  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5231  records loaded in  3.333753824234009 S )
# Social escape  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 21769  records loaded in  3.328935384750366 S )
# Social escape  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 22157  records loaded in  3.351757049560547 S )
# Social escape  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 20729  records loaded in  3.3837640285491943 S )
# Social escape  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 21769  records loaded in  3.4037694931030273 S )
# Social escape  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 22157  records loaded in  3.352757453918457 S )
# Social escape  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 20729  records loaded in  3.3607587814331055 S )
# FollowZone Isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 7352  records loaded in  3.28574275970459 S )
# FollowZone Isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 8314  records loaded in  3.2567358016967773 S )
# FollowZone Isolated  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 7193  records loaded in  3.225728750228882 S )
# Group 3 make  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 793  records loaded in  3.1857199668884277 S )
# Group 3 make  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 743  records loaded in  3.1857194900512695 S )
# Group 3 make  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 726  records loaded in  3.1857199668884277 S )
# Group 4 make  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 222  records loaded in  3.1887199878692627 S )
# Group 4 make  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 193  records loaded in  3.2027335166931152 S )
# Group 4 make  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 198  records loaded in  3.203723669052124 S )
# Group 3 break  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 894  records loaded in  3.2067246437072754 S )
# Group 3 break  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 840  records loaded in  3.2097253799438477 S )
# Group 3 break  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 797  records loaded in  3.2617368698120117 S )
# Group 4 break  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 225  records loaded in  3.2557272911071777 S )
# Group 4 break  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 201  records loaded in  3.2717390060424805 S )
# Group 4 break  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 221  records loaded in  3.2647290229797363 S )
# seq oral oral - oral genital  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 826  records loaded in  3.2907519340515137 S )
# seq oral oral - oral genital  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 873  records loaded in  3.3297524452209473 S )
# seq oral oral - oral genital  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 729  records loaded in  3.276740550994873 S )
# seq oral geni - oral oral  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 813  records loaded in  3.2477335929870605 S )
# seq oral geni - oral oral  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 862  records loaded in  3.225728988647461 S )
# seq oral geni - oral oral  Id( 2 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 761  records loaded in  3.2237367630004883 S )
# *********** DRAWGRAPH
# Move isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 43547  records loaded in  3.4697840213775635 S )
# Move isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 39373  records loaded in  3.4727771282196045 S )
# Move isolated  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 44143  records loaded in  3.488787889480591 S )
# Stop isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 30837  records loaded in  3.6678285598754883 S )
# Stop isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 26827  records loaded in  3.7498390674591064 S )
# Stop isolated  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 33194  records loaded in  3.7608580589294434 S )
# Rear isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 16157  records loaded in  3.351757287979126 S )
# Rear isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 28668  records loaded in  3.451779842376709 S )
# Rear isolated  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 32502  records loaded in  3.424773931503296 S )
# Look down  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 3316  records loaded in  3.2947356700897217 S )
# Look down  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2429  records loaded in  3.280749797821045 S )
# Look down  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4298  records loaded in  3.2847421169281006 S )
# Huddling  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.2467334270477295 S )
# Huddling  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.2702603340148926 S )
# Huddling  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.216726779937744 S )
# WallJump  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 739  records loaded in  3.201723337173462 S )
# WallJump  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 736  records loaded in  3.202723741531372 S )
# WallJump  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 908  records loaded in  3.2047154903411865 S )
# SAP  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4417  records loaded in  3.234739303588867 S )
# SAP  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4776  records loaded in  3.2317302227020264 S )
# SAP  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5454  records loaded in  3.287743091583252 S )
# Move in contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10728  records loaded in  3.291743755340576 S )
# Move in contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10723  records loaded in  3.2707390785217285 S )
# Move in contact  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 9269  records loaded in  3.2877426147460938 S )
# Rear in contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 3602  records loaded in  3.231729745864868 S )
# Rear in contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2816  records loaded in  3.2197277545928955 S )
# Rear in contact  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2483  records loaded in  3.215726613998413 S )
# Side by side Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10873  records loaded in  3.350757122039795 S )
# Side by side Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10820  records loaded in  3.3177497386932373 S )
# Side by side Contact  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 9111  records loaded in  3.2807414531707764 S )
# Side by side Contact, opposite way  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10079  records loaded in  3.2977452278137207 S )
# Side by side Contact, opposite way  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10897  records loaded in  3.2977452278137207 S )
# Side by side Contact, opposite way  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 9279  records loaded in  3.299745559692383 S )
# Oral-oral Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 11052  records loaded in  3.276740312576294 S )
# Oral-oral Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 11344  records loaded in  3.278740882873535 S )
# Oral-oral Contact  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 9003  records loaded in  3.289743423461914 S )
# Oral-genital Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 11398  records loaded in  3.2927439212799072 S )
# Oral-genital Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 12624  records loaded in  3.3227503299713135 S )
# Oral-genital Contact  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 10301  records loaded in  3.277740716934204 S )
# Group2  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5348  records loaded in  3.3107478618621826 S )
# Group2  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5503  records loaded in  3.2947440147399902 S )
# Group2  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4932  records loaded in  3.2717390060424805 S )
# Group3  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2555  records loaded in  3.2587363719940186 S )
# Group3  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2465  records loaded in  3.254734992980957 S )
# Group3  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 2492  records loaded in  3.2467336654663086 S )
# Nest3  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.201723337173462 S )
# Nest3  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.203723907470703 S )
# Nest3  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.2067246437072754 S )
# Train2  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 71  records loaded in  3.3067469596862793 S )
# Train2  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 41  records loaded in  3.2507262229919434 S )
# Train2  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 47  records loaded in  3.196730375289917 S )
# Train3  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 1  records loaded in  3.3327531814575195 S )
# Train3  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 1  records loaded in  3.226728916168213 S )
# Train3  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.2057242393493652 S )
# Train4  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.1987228393554688 S )
# Train4  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.2207276821136475 S )
# Train4  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 0  records loaded in  3.227729082107544 S )
# Social approach  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 43941  records loaded in  3.499791145324707 S )
# Social approach  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 42578  records loaded in  3.5588040351867676 S )
# Social approach  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 42909  records loaded in  3.4997904300689697 S )
# Approach rear  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5218  records loaded in  3.2537434101104736 S )
# Approach rear  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4873  records loaded in  3.229729652404785 S )
# Approach rear  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4006  records loaded in  3.2297301292419434 S )
# Approach contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 32082  records loaded in  3.4037692546844482 S )
# Approach contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 28862  records loaded in  3.42877459526062 S )
# Approach contact  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 24157  records loaded in  3.3837645053863525 S )
# Approach contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 32082  records loaded in  3.441777467727661 S )
# Approach contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 28862  records loaded in  3.427774667739868 S )
# Approach contact  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 24157  records loaded in  3.39176607131958 S )
# Contact  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5076  records loaded in  3.3337531089782715 S )
# Contact  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 5226  records loaded in  3.339754343032837 S )
# Contact  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 4586  records loaded in  3.3207502365112305 S )
# Social escape  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 21769  records loaded in  3.3437554836273193 S )
# Social escape  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 22157  records loaded in  3.3547580242156982 S )
# Social escape  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 20428  records loaded in  3.351757287979126 S )
# Social escape  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 21769  records loaded in  3.3487565517425537 S )
# Social escape  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 22157  records loaded in  3.3707613945007324 S )
# Social escape  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 20428  records loaded in  3.3277604579925537 S )
# FollowZone Isolated  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 7352  records loaded in  3.263737201690674 S )
# FollowZone Isolated  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 8314  records loaded in  3.2477340698242188 S )
# FollowZone Isolated  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 7541  records loaded in  3.2497341632843018 S )
# Group 3 make  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 793  records loaded in  3.2107255458831787 S )
# Group 3 make  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 743  records loaded in  3.202723503112793 S )
# Group 3 make  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 730  records loaded in  3.2107253074645996 S )
# Group 4 make  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 222  records loaded in  3.202723741531372 S )
# Group 4 make  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 193  records loaded in  3.203723669052124 S )
# Group 4 make  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 163  records loaded in  3.1987228393554688 S )
# Group 3 break  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 894  records loaded in  3.1987228393554688 S )
# Group 3 break  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 840  records loaded in  3.2077248096466064 S )
# Group 3 break  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 802  records loaded in  3.2227280139923096 S )
# Group 4 break  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 225  records loaded in  3.203723669052124 S )
# Group 4 break  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 201  records loaded in  3.2057244777679443 S )
# Group 4 break  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 164  records loaded in  3.2067246437072754 S )
# seq oral oral - oral genital  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 826  records loaded in  3.217726945877075 S )
# seq oral oral - oral genital  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 873  records loaded in  3.226728916168213 S )
# seq oral oral - oral genital  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 655  records loaded in  3.228729724884033 S )
# seq oral geni - oral oral  Id( 1 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 813  records loaded in  3.2207279205322266 S )
# seq oral geni - oral oral  Id( 3 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 862  records loaded in  3.2447330951690674 S )
# seq oral geni - oral oral  Id( 4 , None , None , None ) Min/maxFrame: ( 0 / 2484000 ) Loaded ( 675  records loaded in  3.212725877761841 S )
