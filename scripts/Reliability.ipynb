# %% [markdown]
# ## Reliability
# This script allows to have an overview of the quality of the tracking for the whole experiment.
#
#
# *Run after rebuilding events, and keep in mind that animals are very immobile when they sleep which makes the detection of the position of each animal individually very difficult. Therefore the detection rate over day and night experiments might be low (up to 40%).*

# %%
'''
Created on 26 avr. 2019

@author: Elodie
'''
import sys
sys.path.insert(1, "../")

import sqlite3
import math
import time
import datetime
from lmtanalysis.Animal import *
import matplotlib.pyplot as plt
from lmtanalysis.Event import *
from lmtanalysis.Measure import *
import os
from tkinter.filedialog import askopenfilename
from lmtanalysis.Util import getMinTMaxTAndFileNameInput, getFileNameInput,\
    getNumberOfFrames
from lmtanalysis.FileUtil import getFilesToProcess

# %%
if __name__ == '__main__':
    
    behaviouralEvents = ["Contact", "Oral-oral Contact", "Oral-genital Contact", "Side by side Contact", "Side by side Contact, opposite way", "Social approach", "Social escape", "Approach contact", "Approach rear", "Break contact", "Get away", "FollowZone Isolated", "Train2", "Group2", "Group3", "Group 3 break", "Group 3 make", "Group4", "Group 4 break", "Group 4 make", "Huddling", "Move isolated", "Move in contact", "Nest3", "Nest4", "Rearing", "Rear isolated", "Rear in contact", "Stop isolated", "WallJump", "Water Zone", "USV seq"]
    
    files = getFilesToProcess()
    
    text_file = getFileNameInput()
    
    for file in files:
        print( file )
        connection = sqlite3.connect( file )
        c = connection.cursor()
        text_file.write( file )
        text_file.write("\n")
        
        ##########################################################################
        '''Compute total recording duration'''
        print ("##############################################################")
        query = "SELECT MIN(TIMESTAMP) FROM FRAME";
        c.execute( query )
        rows = c.fetchall()
        for row in rows:
            realStartTime = datetime.datetime.fromtimestamp(row[0]/1000)
            realStartInSeconds = row[0]/1000
        
        #return realStartTime
        print( "Time of experiment start: {}".format(realStartTime) )
        text_file.write ( "Time of experiment start: {}\n".format(realStartTime) )
        
        query = "SELECT MAX(TIMESTAMP) FROM FRAME";
        c.execute( query )
        rows = c.fetchall()
        for row in rows:
            realEndTime = datetime.datetime.fromtimestamp(row[0]/1000)
            realEndInSeconds = row[0]/1000
        
        #return realEndTime
        print( "Time of experiment end: {}".format(realEndTime) )
        text_file.write( "Time of experiment end: {}\n".format(realEndTime) )
        #Total duration of experiment based on timestamp
        realDurationInSeconds = realEndInSeconds - realStartInSeconds + 1
        print( "Real duration of experiment: {} s ({} frames)".format( realDurationInSeconds, realDurationInSeconds*30 ) )
        text_file.write( "Real duration of experiment: {} s ({} frames)\n".format( realDurationInSeconds, realDurationInSeconds*30 ) )
        
        ##########################################################################
        '''Compute the total number of frames recorded'''
        #nbFramesRecorded = getNumberOfFrames(file)
        print ("##############################################################")
        query = "SELECT * FROM FRAME";
        c.execute( query )
        framesRecorded = c.fetchall()
        nbFramesRecorded = len(framesRecorded)
        print ( "Number of frames recorded:  {} frames ({} seconds or {} minutes or {} hours or {} days)".format(nbFramesRecorded, nbFramesRecorded/oneSecond, nbFramesRecorded/oneMinute, nbFramesRecorded/oneHour, nbFramesRecorded/oneDay))
        text_file.write( "Number of frames recorded:  {} frames ({} seconds or {} minutes or {} hours or {} days)\n".format(nbFramesRecorded, nbFramesRecorded/oneSecond, nbFramesRecorded/oneMinute, nbFramesRecorded/oneHour, nbFramesRecorded/oneDay) )
        
        query = "SELECT MIN(FRAMENUMBER) FROM FRAME";
        c.execute( query )
        minFrames = c.fetchall()
        for minFrame in minFrames:
            startFrame = minFrame[0]
        
        query = "SELECT MAX(FRAMENUMBER) FROM FRAME";
        c.execute( query )
        maxFrames = c.fetchall()
        for maxFrame in maxFrames:
            endFrame = maxFrame[0]  
        
        durationExp = endFrame - startFrame +1
        print ("Experiment duration based on frames: {} frames".format(durationExp) ) 
        
        nbOmittedFrames = realDurationInSeconds*oneSecond - nbFramesRecorded
        print ( "Number of frames omitted: {} ({} % of the total experiment duration)".format (nbOmittedFrames, 100*nbOmittedFrames/(realDurationInSeconds*oneSecond)) )
        text_file.write( "Number of frames omitted: {} ({} % of the total experiment duration)\n".format (nbOmittedFrames, 100*nbOmittedFrames/(realDurationInSeconds*oneSecond)) )
        text_file.write("\n")
        
        print ("##############################################################")
        ##########################################################################
        '''Number of animals detected and rate of detection'''
        pool = AnimalPool( )
        pool.loadAnimals( connection )
        pool.loadDetection( start = startFrame, end = endFrame, lightLoad=True)
        print ("##############################################################")
        
        for animal in pool.animalDictionnary.keys():
            
            nbOfDetections = pool.animalDictionnary[animal].getNumberOfDetection(tmin = startFrame, tmax = endFrame)
            missedDetection = 1-nbOfDetections/nbFramesRecorded
            
            print ( "Animal {}: {} missed detections over {} frames recorded ({} %)".format( pool.animalDictionnary[animal].RFID, nbFramesRecorded-nbOfDetections, nbFramesRecorded, missedDetection*100 ) )
            text_file.write( "Animal {}: {} missed detections over {} frames recorded ({} %)\n".format( pool.animalDictionnary[animal].RFID, nbFramesRecorded-nbOfDetections, nbFramesRecorded, missedDetection*100 ) )
            '''Note: The score can be low, if the animals are often huddled in the nest and not identified individually.'''
        
        ##########################################################################
        '''Number of RFID match'''
        print ("##############################################################")
        
        for animal in pool.animalDictionnary.keys():
            rfidMatchTimeLine = EventTimeLine( connection, "RFID MATCH", idA = animal )
            rfidMismatchTimeLine = EventTimeLine( connection, "RFID MISMATCH", idA = animal )
            nbOfRfidMatch = rfidMatchTimeLine.getNumberOfEvent(minFrame=startFrame, maxFrame=endFrame)
            nbOfRfidMismatch = rfidMismatchTimeLine.getNumberOfEvent(minFrame=startFrame, maxFrame=endFrame)
            print( "Number of RFID match for animal {}: {} (rate: {} events/min)".format( pool.animalDictionnary[animal].RFID, nbOfRfidMatch, nbOfRfidMatch/(durationExp*30*60) ) )
            print( "Number of RFID mismatch for animal {}: {} (rate: {} events/min)".format( pool.animalDictionnary[animal].RFID, nbOfRfidMismatch, nbOfRfidMismatch/(durationExp*30*60) ) )
            text_file.write( "Number of RFID match for animal {}: {} (rate: {} events/min)\n".format( pool.animalDictionnary[animal].RFID, nbOfRfidMatch, nbOfRfidMatch/(durationExp*30*60) ) )
            text_file.write( "Number of RFID mismatch for animal {}: {} (rate: {} events/min)\n".format( pool.animalDictionnary[animal].RFID, nbOfRfidMismatch, nbOfRfidMismatch/(durationExp*30*60) ) )
            
        print ("##############################################################")
        ##########################################################################
        '''Check events'''
        text_file.write( "\n" )
        text_file.write("Total number of each event type:\n")
        for event in behaviouralEvents:
            eventTimeLine = EventTimeLine( connection, event )
            nbOfEvents = eventTimeLine.getNumberOfEvent(minFrame=None, maxFrame=None)
            text_file.write("{}:\t {}\n".format(event, nbOfEvents))
        
        text_file.write( "\n" )    
        text_file.write( "##############################################################\n" )
        ##########################################################################
    text_file.write( "\n" )
    
    text_file.close()
    
    print("job done")
# Out:
# File name : reliability_experiment20
# D:/live mouse tracker data/Experiment 20/Experiment 20.sqlite
# ##############################################################
# Time of experiment start: 2020-06-06 11:45:06.058000
# Time of experiment end: 2020-06-08 10:54:26.324000
# Real duration of experiment: 169761.265999794 s (5092837.97999382 frames)
# ##############################################################
# Number of frames recorded:  5092777 frames (169759.23333333334 seconds or 2829.3205555555555 minutes or 47.15534259259259 hours or 1.9648059413580248 days)
# Experiment duration based on frames: 5092777 frames
# Number of frames omitted: 60.97999382019043 (0.0011973676378423572 % of the total experiment duration)
# ##############################################################
# Loading animals.
# Fields available in lmtanalysis:  ['ID', 'RFID', 'GENOTYPE', 'NAME']
# SQL Query: SELECT ID,RFID,NAME,GENOTYPE FROM ANIMAL ORDER BY GENOTYPE
# Animal Id:1 Name:A RFID:000022986409 Genotype:None User1:None
# Animal Id:2 Name:B RFID:000022986408 Genotype:None User1:None
# Animal Id:3 Name:C RFID:000022986387 Genotype:None User1:None
# Animal Id:4 Name:D RFID:000022986562 Genotype:None User1:None
# Animal Id:1 Name:A RFID:000022986409 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=1 AND FRAMENUMBER>=1 AND FRAMENUMBER<=5092777
# Animal Id:1 Name:A RFID:000022986409 Genotype:None User1:None   2972002  detections loaded in 92.99626731872559 seconds.
# Animal Id:2 Name:B RFID:000022986408 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=2 AND FRAMENUMBER>=1 AND FRAMENUMBER<=5092777
# Animal Id:2 Name:B RFID:000022986408 Genotype:None User1:None   3098939  detections loaded in 111.92303204536438 seconds.
# Animal Id:3 Name:C RFID:000022986387 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=3 AND FRAMENUMBER>=1 AND FRAMENUMBER<=5092777
# Animal Id:3 Name:C RFID:000022986387 Genotype:None User1:None   3167755  detections loaded in 103.42375588417053 seconds.
# Animal Id:4 Name:D RFID:000022986562 Genotype:None User1:None : Loading detection.
# SELECT FRAMENUMBER, MASS_X, MASS_Y FROM DETECTION WHERE ANIMALID=4 AND FRAMENUMBER>=1 AND FRAMENUMBER<=5092777
# Animal Id:4 Name:D RFID:000022986562 Genotype:None User1:None   3079470  detections loaded in 122.90567684173584 seconds.
# ##############################################################
# Animal 000022986409: 2120775 missed detections over 5092777 frames recorded (41.642801167221734 %)
# Animal 000022986408: 1993838 missed detections over 5092777 frames recorded (39.1503103316717 %)
# Animal 000022986387: 1925022 missed detections over 5092777 frames recorded (37.79906326155651 %)
# Animal 000022986562: 2013307 missed detections over 5092777 frames recorded (39.53259685236562 %)
# ##############################################################
# RFID MATCH  Id( 1 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 45845  records loaded in  177.28017449378967 S )
# RFID MISMATCH  Id( 1 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 697  records loaded in  9.288097620010376 S )
# Number of RFID match for animal 000022986409: 45845 (rate: 5.001091633198242e-06 events/min)
# Number of RFID mismatch for animal 000022986409: 697 (rate: 7.603361039020994e-08 events/min)
# RFID MATCH  Id( 2 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 42555  records loaded in  1.4143195152282715 S )
# RFID MISMATCH  Id( 2 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 722  records loaded in  1.2362797260284424 S )
# Number of RFID match for animal 000022986408: 42555 (rate: 4.642195538243019e-06 events/min)
# Number of RFID mismatch for animal 000022986408: 722 (rate: 7.876078436403383e-08 events/min)
# RFID MATCH  Id( 3 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 79767  records loaded in  1.5943610668182373 S )
# RFID MISMATCH  Id( 3 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 658  records loaded in  1.3363018035888672 S )
# Number of RFID match for animal 000022986387: 79767 (rate: 8.701539454800397e-06 events/min)
# Number of RFID mismatch for animal 000022986387: 658 (rate: 7.177921899104468e-08 events/min)
# RFID MATCH  Id( 4 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 62198  records loaded in  1.4533405303955078 S )
# RFID MISMATCH  Id( 4 , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 677  records loaded in  1.206272840499878 S )
# Number of RFID match for animal 000022986562: 62198 (rate: 6.784990672955923e-06 events/min)
# Number of RFID mismatch for animal 000022986562: 677 (rate: 7.385187121115084e-08 events/min)
# ##############################################################
# Contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 23254  records loaded in  2.4559051990509033 S )
# Oral-oral Contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 27858  records loaded in  1.6683769226074219 S )
# Oral-genital Contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 36035  records loaded in  1.6653764247894287 S )
# Side by side Contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 26377  records loaded in  1.5433650016784668 S )
# Side by side Contact, opposite way  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 24554  records loaded in  1.5413477420806885 S )
# Social approach  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 126215  records loaded in  2.6365957260131836 S )
# Social escape  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 94565  records loaded in  1.8964426517486572 S )
# Approach contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.2012712955474854 S )
# Approach rear  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 15315  records loaded in  1.3163268566131592 S )
# Break contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 26290  records loaded in  1.4543278217315674 S )
# Get away  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 135902  records loaded in  2.913658857345581 S )
# FollowZone Isolated  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 32940  records loaded in  1.3162972927093506 S )
# Train2  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 364  records loaded in  1.1532599925994873 S )
# Group2  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 15618  records loaded in  1.451329231262207 S )
# Group3  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 4063  records loaded in  1.4343245029449463 S )
# Group 3 break  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3589  records loaded in  1.2632851600646973 S )
# Group 3 make  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 3650  records loaded in  1.3663077354431152 S )
# Group4  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 791  records loaded in  1.2282769680023193 S )
# Group 4 break  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 609  records loaded in  1.1792662143707275 S )
# Group 4 make  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 592  records loaded in  1.1762700080871582 S )
# Huddling  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.1662631034851074 S )
# Move isolated  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 147751  records loaded in  4.396263122558594 S )
# Move in contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 31226  records loaded in  1.441831350326538 S )
# Nest3  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.2072727680206299 S )
# Nest4  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.2552831172943115 S )
# Rearing  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 5128  records loaded in  3.4262802600860596 S )
# Rear isolated  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 18994  records loaded in  1.2812891006469727 S )
# Rear in contact  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 14351  records loaded in  1.2182765007019043 S )
# Stop isolated  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.1832666397094727 S )
# WallJump  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.184267282485962 S )
# Water Zone  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.1692802906036377 S )
# USV seq  Id( None , None , None , None ) Min/maxFrame: ( None / None ) Loaded ( 0  records loaded in  1.1672635078430176 S )
# job done
